# %%
import base64
import io
import math
import operator
import random
import time
import urllib

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
import rtree

# %%
import shapefile

# %%
from shapely.geometry import Polygon, Point

# %%
import pyproj

# %%
def slice_at(plist, indices):
    '''
    Slices the list ll at the indices indicated.
    '''
    indices.append(len(plist))
    for fro, to in zip(indices, indices[1:]):
        yield plist[fro:to]

# %%
def plot_country(name, parts, center, radius):
    fig, ax = plt.subplots(figsize=(1.8, 1.8))

    circle = plt.Circle(center, radius, color='k', fill=False)
    for part in parts:
        #color = random.choice('bgrcmk')
        color = 'k'
        for point1, point2 in zip(part, part[1:]):
            ax.plot(
                [point1[0], point2[0]],
                [point1[1], point2[1]],
                color+'-')
    ax.add_artist(circle)
    ax.set_aspect('equal', 'datalim')
    imgdata = io.BytesIO()
    #ax.set_title(name)
    plt.axis('off')
    #plt.savefig(name.lower().replace(' ', '-') + '.png', transparent=True)
    #plt.show()
    plt.savefig('tmp.png', format='png', transparent=True)
    img = Image.open('tmp.png')
    png_info = img.info
    img.convert('P').save(imgdata, 'PNG', **png_info)
    imgdata.seek(0)
    plt.close(fig)
    return imgdata

# %%
def neighbours(center, radius, delta):
    cmov = delta
    rmov = delta
    cms = [cmov*20, cmov, 0, -cmov, -cmov*20]
    rms = [rmov*20, rmov, 0, -rmov, -rmov*20]
    for cx_mov in cms:
        for cy_mov in cms:
            for r_mov in rms:
                if radius + r_mov > 0:
                    yield ((center[0] + cx_mov, center[1] + cy_mov),
                           radius + r_mov)

# %%
def maxmin(arr):
    _max = arr[0]
    _min = arr[0]
    for x in arr:
        if x > _max:
            _max = x
        elif x < _min:
            _min = x
    return _max, _min

# %%
def heuristic(polygons, index, c, r, delta, iters=200):
    best_coeff = 0
    parts_area = sum(map(lambda x: x.area, polygons))
    is_ = 0
    for _ in range(iters):
        is_ += 1
        mejoro = False
        for c_, r_ in neighbours(c, r, delta):
            circle = Point(c_).buffer(r_)
            indices = range(len(polygons))
            if circle.bounds != ():
                indices = [int(i) for i in index.intersection(circle.bounds)]
            else:
                print('WARNING: circle.bounds == (). '\
                      'center = %s, radius = %.3f' % (str(c_), r_))
            intersection_area = sum(
                [polygons[i].intersection(circle).area for i in indices])
            coeff = intersection_area / max(math.pi * r_ * r_, parts_area)
            #print(c_, r_)
            #print(intersection_area, circle_area, parts_area)
            if coeff > best_coeff:
                mejoro = True
                c = c_
                r = r_
                best_coeff = coeff
        if not mejoro:
            break
    return c, r, best_coeff, is_

# %%
def circle_inside(xmin, ymin, xmax, ymax):
    center = [(xmin + xmax) / 2, (ymin + ymax) / 2]
    radius = min((xmax - xmin) / 2, (ymax - ymin) / 2)
    return center, radius

# %%
def circle_outside(xmin, ymin, xmax, ymax):
    center = [(xmin + xmax) / 2, (ymin + ymax) / 2]
    radius = math.sqrt((xmax - xmin)**2.0 + (ymax - ymin)**2.0) / 2
    return center, radius

# %%
def analyze_both_circles(polys, index, min_x, min_y, max_x, max_y):
    cinside, rinside = circle_inside(min_x, min_y, max_x, max_y)
    coutside, routside = circle_outside(min_x, min_y, max_x, max_y)
    c_i, r_i, best_i, iin = heuristic(
        polys, index, cinside, rinside, rinside / 200)
    print('[%d, ' % iin, end='', flush=True)
    c_o, r_o, best_o, iout = heuristic(
        polys, index, coutside, routside, routside / 200)
    print('%d]' % iout)
    best_coeff_ = max(best_i, best_o)
    center_ = c_i if best_i > best_o else c_o
    radius_ = r_i if best_i > best_o else r_o
    return center_, radius_, best_coeff_

# %%
def find_best_circle(parts, minx, miny, maxx, maxy):
    polys = [Polygon(part).buffer(0) for part in parts]
    index = rtree.index.Index()
    for i, poly in enumerate(polys):
        index.insert(i, poly.bounds)
    print('Analyzing best overall circle...  Iterations: ', end='', flush=True)
    c, r, best_coeff = analyze_both_circles(
        polys, index, minx, miny, maxx, maxy)
    best_polygons = []
    if len(polys) > 1:
        polygons_area = sorted(
            [(poly, poly.area) for poly in polys],
            key=lambda x: x[1], reverse=True)
        areas = list(map(lambda r: r[1], polygons_area))
        if areas[0] > sum(areas[1:]):
            best_polygons = [polygons_area[0][0]]
        else:
            best_polygons = list(map(lambda x: x[0], polygons_area))[:5]
    i = 0
    for part in best_polygons:
        if len(polys) == 1:
            break
        i += 1
        print('Analyzing best part circle... (%d out of %d) Iterations: ' \
            % (i, len(polys)), end='', flush=True)
        x, y = part.exterior.coords.xy
        max_x, min_x = maxmin(x)
        max_y, min_y = maxmin(y)
        center_, radius_, best_coeff_ = analyze_both_circles(
            polys, index, min_x, min_y, max_x, max_y)
        if best_coeff_ > best_coeff:
            c = center_
            r = radius_
            best_coeff = best_coeff_
    # fine tune it.
    print('Fine-tuning the circle... Iterations: ', end='', flush=True)
    c, r, best_coeff, iters = heuristic(polys, index, c, r, r / 1000, 1000)
    print('[%d]' % iters)
    return c, r, best_coeff

# %%
def tuple2list(t):
    t = tuple(t)[0]
    return [t[0], t[1]]

# %%
def concat(ls):
    return [j for i in ls for j in i]

# %%
def mean(ls):
    return float(sum(ls)) / len(ls)

# %%
INPUT_FILE = 'LA'
FROM_PROJ = '+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs'

# %%
def main():
    countries = shapefile.Reader(INPUT_FILE).shapeRecords()
    results = {}

# %%
fields =shapefile.Reader(INPUT_FILE).fields[1:] 
field_names = [field[0] for field in fields] 
# construction of a dctionary field_name:value  
for r in shapefile.Reader(INPUT_FILE).shapeRecords():  
     atr = dict(zip(field_names, r.record))

# %%
print(field_names)
# Out:
# ['objectid', 'lad17cd', 'lad17nm', 'lad17nmw', 'bng_e', 'bng_n', 'long', 'lat', 'st_areasha', 'st_lengths']

# %%
country = field_names[2]

# %%
print(country)
# Out:
# lad17nm

# %%
def main():
    countries = shapefile.Reader(INPUT_FILE).shapeRecords()
    results = {}

    for country in countries:
        t0 = time.process_time()
        name = country.record[2]
        # if name != 'Nauru': continue
        print('==== %s (%d -> %d) ====' % (
            name, len(country.shape.parts), len(country.shape.points)))
        points = list(map(lambda x: x, country.shape.points))

        parts_ = list(country.shape.parts) + [len(country.shape.points)]
        largest_part = (0, 1)
        for x1, x2 in zip(parts_, parts_[1:]):
            if x2 - x1 > largest_part[1] - largest_part[0]:
                largest_part = (x1, x2)
        print(parts_, largest_part)

        # Get the random points from the largest part.
        random_points = list(
            map(
                list,
                random.sample(points[largest_part[0]:largest_part[1]], 2)))

        # Get the middle points between them.
        lon, lat = list(
            pyproj.Geod(ellps='WGS84').npts(
                random_points[0][0], random_points[0][1],
                random_points[1][0], random_points[1][1],
                1)  # Just 1 point in-between them.
            )[0]

#         to_proj = '+proj=aeqd +R=6371000 +lat_0=%.2f +lon_0=%.2f ' \
#                   '+no_defs' % (lat, lon)
#         print('Projection: %s' % to_proj)

#         transform = lambda g: pyproj.transform(
#             pyproj.Proj(FROM_PROJ),
#             pyproj.Proj(to_proj),
#             g[0], g[1])
#         points = list(map(transform, points))

        parts = list(slice_at(points, country.shape.parts))
        max_xs, min_xs = maxmin(list(map(lambda t: t[0], points)))
        max_ys, min_ys = maxmin(list(map(lambda t: t[1], points)))

        center, radius, best_coeff = find_best_circle(
            parts, min_xs, min_ys, max_xs, max_ys)

        print('Result info: %f (%.4f, %.4f) %.4f' \
            % (best_coeff, center[0], center[1], radius))
        uri = 'data:image/png;base64,' + urllib.parse.quote(
            base64.b64encode(
                plot_country(name, parts, center, radius).getvalue()))
        print('Finished plotting %s.' % name)
        results[name] = (best_coeff, '<img src="%s" />' % uri)

    f = open('table', 'w')
    # Does python use theorems for free?
    # (https://www.mpi-sws.org/~dreyer/tor/papers/wadler.pdf)
    f.write(
        '\n'.join(
            map(lambda s: ' | '.join(map(str, s)),
                map(lambda r: [r[0]+1, r[1][0],
                               '%.3f' % r[1][1][0],
                               r[1][1][1]],
                    enumerate(
                        sorted(results.items(),
                               key=lambda z: (operator.itemgetter(1)(z))[0],
                               reverse=True))))))8
    f.close()

# %%
main()
# Out:
# ==== Hartlepool (2 -> 394) ====
# [0, 390, 394] (0, 390)
# Analyzing best overall circle...  Iterations: [15, 17]
# Analyzing best part circle... (1 out of 2) Iterations: [15, 17]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.880241 (448080.1224, 531070.8977) 5455.6313
# Finished plotting Hartlepool.
# ==== Middlesbrough (2 -> 216) ====
# [0, 207, 216] (0, 207)
# Analyzing best overall circle...  Iterations: [12, 14]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.843015 (450166.2630, 516783.7424) 4141.6191
# Finished plotting Middlesbrough.
# ==== Redcar and Cleveland (3 -> 378) ====
# [0, 364, 374, 378] (0, 364)
# Analyzing best overall circle...  Iterations: [14, 22]
# Analyzing best part circle... (1 out of 3) Iterations: [15, 23]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.762413 (462055.5827, 518365.2487) 8831.5889
# Finished plotting Redcar and Cleveland.
# ==== Stockton-on-Tees (2 -> 671) ====
# [0, 665, 671] (0, 665)
# Analyzing best overall circle...  Iterations: [14, 14]
# Analyzing best part circle... (1 out of 2) Iterations: [14, 14]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.776707 (443414.0101, 518785.3164) 8080.9593
# Finished plotting Stockton-on-Tees.
# ==== Kingston upon Hull, City of (2 -> 279) ====
# [0, 153, 279] (0, 153)
# Analyzing best overall circle...  Iterations: [9, 11]
# Analyzing best part circle... (1 out of 2) Iterations: [14, 11]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.806658 (510301.4756, 431359.4347) 4769.3934
# Finished plotting Kingston upon Hull, City of.
# ==== East Riding of Yorkshire (5 -> 1743) ====
# [0, 1440, 1566, 1732, 1738, 1743] (0, 1440)
# Analyzing best overall circle...  Iterations: [10, 12]
# Analyzing best part circle... (1 out of 5) Iterations: [16, 16]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.765507 (496966.1866, 443301.8948) 27682.1800
# Finished plotting East Riding of Yorkshire.
# ==== Luton (1 -> 106) ====
# [0, 106] (0, 106)
# Analyzing best overall circle...  Iterations: [11, 15]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.813233 (508094.7956, 222900.6742) 3714.2886
# Finished plotting Luton.
# ==== Darlington (1 -> 484) ====
# [0, 484] (0, 484)
# Analyzing best overall circle...  Iterations: [14, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.780242 (428719.0839, 517591.6230) 7930.6001
# Finished plotting Darlington.
# ==== Halton (2 -> 322) ====
# [0, 157, 322] (157, 322)
# Analyzing best overall circle...  Iterations: [9, 25]
# Analyzing best part circle... (1 out of 2) Iterations: [21, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.725771 (352682.1814, 383956.4338) 5017.4840
# Finished plotting Halton.
# ==== Leicester (1 -> 270) ====
# [0, 270] (0, 270)
# Analyzing best overall circle...  Iterations: [15, 14]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.867410 (459315.1926, 304938.0822) 4833.0937
# Finished plotting Leicester.
# ==== Warrington (1 -> 536) ====
# [0, 536] (0, 536)
# Analyzing best overall circle...  Iterations: [9, 7]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.867260 (362822.2716, 389410.6563) 7582.3594
# Finished plotting Warrington.
# ==== Blackburn with Darwen (1 -> 337) ====
# [0, 337] (0, 337)
# Analyzing best overall circle...  Iterations: [14, 12]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.750484 (369765.2836, 420302.5975) 6603.8171
# Finished plotting Blackburn with Darwen.
# ==== Blackpool (1 -> 124) ====
# [0, 124] (0, 124)
# Analyzing best overall circle...  Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.694359 (332261.4852, 435116.4296) 3332.6339
# Finished plotting Blackpool.
# ==== North East Lincolnshire (1 -> 362) ====
# [0, 362] (0, 362)
# Analyzing best overall circle...  Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.749900 (523813.4643, 406424.3909) 7811.9647
# Finished plotting North East Lincolnshire.
# ==== York (1 -> 613) ====
# [0, 613] (0, 613)
# Analyzing best overall circle...  Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.909918 (461560.8261, 452023.5592) 9307.8920
# Finished plotting York.
# ==== North Lincolnshire (3 -> 760) ====
# [0, 519, 704, 760] (0, 519)
# Analyzing best overall circle...  Iterations: [7, 22]
# Analyzing best part circle... (1 out of 3) Iterations: [14, 11]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.748047 (489706.0440, 409085.8468) 16406.9088
# Finished plotting North Lincolnshire.
# ==== Derby (1 -> 243) ====
# [0, 243] (0, 243)
# Analyzing best overall circle...  Iterations: [11, 8]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.889704 (435870.2089, 335238.1539) 4985.9862
# Finished plotting Derby.
# ==== Rutland (1 -> 830) ====
# [0, 830] (0, 830)
# Analyzing best overall circle...  Iterations: [16, 9]
# Fine-tuning the circle... Iterations: [8]
# Result info: 0.874853 (490734.0657, 307933.4068) 11192.7209
# Finished plotting Rutland.
# ==== Nottingham (1 -> 254) ====
# [0, 254] (0, 254)
# Analyzing best overall circle...  Iterations: [8, 18]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.815249 (455425.0317, 341527.8349) 4872.7310
# Finished plotting Nottingham.
# ==== Herefordshire, County of (1 -> 1940) ====
# [0, 1940] (0, 1940)
# Analyzing best overall circle...  Iterations: [9, 10]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.907112 (349629.5526, 245325.4916) 26354.2933
# Finished plotting Herefordshire, County of.
# ==== Telford and Wrekin (1 -> 637) ====
# [0, 637] (0, 637)
# Analyzing best overall circle...  Iterations: [10, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.842914 (367222.8944, 315515.4990) 9611.9242
# Finished plotting Telford and Wrekin.
# ==== Stoke-on-Trent (1 -> 346) ====
# [0, 346] (0, 346)
# Analyzing best overall circle...  Iterations: [10, 18]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.713509 (389308.5743, 346197.1194) 5456.1582
# Finished plotting Stoke-on-Trent.
# ==== Bath and North East Somerset (1 -> 850) ====
# [0, 850] (0, 850)
# Analyzing best overall circle...  Iterations: [16, 22]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.788660 (369067.0794, 163034.8770) 10577.3119
# Finished plotting Bath and North East Somerset.
# ==== Southend-on-Sea (2 -> 208) ====
# [0, 158, 208] (0, 158)
# Analyzing best overall circle...  Iterations: [22, 8]
# Analyzing best part circle... (1 out of 2) Iterations: [22, 8]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.605891 (585805.5036, 186767.4992) 3643.8911
# Finished plotting Southend-on-Sea.
# ==== Bristol, City of (2 -> 572) ====
# [0, 568, 572] (0, 568)
# Analyzing best overall circle...  Iterations: [14, 18]
# Analyzing best part circle... (1 out of 2) Iterations: [8, 21]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.759685 (359016.6425, 173321.6553) 5909.0045
# Finished plotting Bristol, City of.
# ==== Torbay (2 -> 538) ====
# [0, 532, 538] (0, 532)
# Analyzing best overall circle...  Iterations: [15, 20]
# Analyzing best part circle... (1 out of 2) Iterations: [15, 20]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.567739 (289034.2907, 62106.4886) 4478.0813
# Finished plotting Torbay.
# ==== North Somerset (2 -> 911) ====
# [0, 898, 911] (0, 898)
# Analyzing best overall circle...  Iterations: [8, 8]
# Analyzing best part circle... (1 out of 2) Iterations: [13, 11]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.807398 (345505.1008, 166751.6918) 10924.3581
# Finished plotting North Somerset.
# ==== Bournemouth (2 -> 233) ====
# [0, 229, 233] (0, 229)
# Analyzing best overall circle...  Iterations: [16, 12]
# Analyzing best part circle... (1 out of 2) Iterations: [16, 12]
# Fine-tuning the circle... Iterations: [8]
# Result info: 0.753642 (409247.0913, 94058.0735) 3833.7366
# Finished plotting Bournemouth.
# ==== South Gloucestershire (1 -> 749) ====
# [0, 749] (0, 749)
# Analyzing best overall circle...  Iterations: [12, 16]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.862765 (368235.0413, 182178.9932) 12579.8621
# Finished plotting South Gloucestershire.
# ==== Slough (1 -> 202) ====
# [0, 202] (0, 202)
# Analyzing best overall circle...  Iterations: [16, 19]
# Fine-tuning the circle... Iterations: [8]
# Result info: 0.639689 (496446.6521, 180514.3571) 3219.3188
# Finished plotting Slough.
# ==== Plymouth (4 -> 643) ====
# [0, 611, 625, 639, 643] (0, 611)
# Analyzing best overall circle...  Iterations: [11, 13]
# Analyzing best part circle... (1 out of 4) Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.849031 (249550.8467, 56616.8503) 5042.3585
# Finished plotting Plymouth.
# ==== Poole (5 -> 396) ====
# [0, 366, 376, 384, 392, 396] (0, 366)
# Analyzing best overall circle...  Iterations: [11, 16]
# Analyzing best part circle... (1 out of 5) Iterations: [11, 16]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.801728 (402776.0547, 94003.4297) 4540.5095
# Finished plotting Poole.
# ==== Swindon (1 -> 589) ====
# [0, 589] (0, 589)
# Analyzing best overall circle...  Iterations: [14, 16]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.834608 (418169.2951, 185314.8160) 8558.4213
# Finished plotting Swindon.
# ==== Peterborough (1 -> 435) ====
# [0, 435] (0, 435)
# Analyzing best overall circle...  Iterations: [12, 17]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.719769 (518722.1893, 302666.5748) 10454.5724
# Finished plotting Peterborough.
# ==== Thurrock (3 -> 459) ====
# [0, 434, 446, 459] (0, 434)
# Analyzing best overall circle...  Iterations: [13, 18]
# Analyzing best part circle... (1 out of 3) Iterations: [13, 18]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.812661 (563329.0092, 181178.9821) 7208.7851
# Finished plotting Thurrock.
# ==== Medway (13 -> 1251) ====
# [0, 687, 996, 1032, 1074, 1107, 1131, 1167, 1185, 1199, 1219, 1238, 1245, 1251] (0, 687)
# Analyzing best overall circle...  Iterations: [4, 17]
# Analyzing best part circle... (1 out of 13) Iterations: [10, 12]
# Fine-tuning the circle... Iterations: [8]
# Result info: 0.721402 (577218.1463, 171519.9905) 7846.3248
# Finished plotting Medway.
# ==== Bracknell Forest (1 -> 180) ====
# [0, 180] (0, 180)
# Analyzing best overall circle...  Iterations: [9, 15]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.782357 (488672.2881, 169578.9917) 5901.1329
# Finished plotting Bracknell Forest.
# ==== Windsor and Maidenhead (1 -> 402) ====
# [0, 402] (0, 402)
# Analyzing best overall circle...  Iterations: [21, 11]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.629545 (488203.1444, 178650.0281) 7949.0224
# Finished plotting Windsor and Maidenhead.
# ==== West Berkshire (1 -> 762) ====
# [0, 762] (0, 762)
# Analyzing best overall circle...  Iterations: [15, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.771581 (447715.5829, 171192.7903) 14969.6154
# Finished plotting West Berkshire.
# ==== Reading (1 -> 216) ====
# [0, 216] (0, 216)
# Analyzing best overall circle...  Iterations: [11, 12]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.826953 (471005.7002, 173227.0299) 3584.8598
# Finished plotting Reading.
# ==== Wokingham (1 -> 365) ====
# [0, 365] (0, 365)
# Analyzing best overall circle...  Iterations: [14, 19]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.793352 (476949.7867, 169099.6558) 7545.2908
# Finished plotting Wokingham.
# ==== Milton Keynes (1 -> 480) ====
# [0, 480] (0, 480)
# Analyzing best overall circle...  Iterations: [10, 11]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.857489 (486854.1133, 243084.6907) 9909.4909
# Finished plotting Milton Keynes.
# ==== Brighton and Hove (1 -> 229) ====
# [0, 229] (0, 229)
# Analyzing best overall circle...  Iterations: [12, 13]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.744512 (530492.8455, 106838.8977) 5135.8830
# Finished plotting Brighton and Hove.
# ==== Portsmouth (5 -> 340) ====
# [0, 199, 317, 330, 335, 340] (0, 199)
# Analyzing best overall circle...  Iterations: [17, 11]
# Analyzing best part circle... (1 out of 5) Iterations: [16, 15]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.724052 (465746.1227, 103210.4448) 3584.7725
# Finished plotting Portsmouth.
# ==== Southampton (1 -> 324) ====
# [0, 324] (0, 324)
# Analyzing best overall circle...  Iterations: [12, 10]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.781890 (442102.2598, 113462.4785) 3986.5793
# Finished plotting Southampton.
# ==== Isle of Wight (5 -> 1212) ====
# [0, 1195, 1200, 1204, 1208, 1212] (0, 1195)
# Analyzing best overall circle...  Iterations: [12, 11]
# Analyzing best part circle... (1 out of 5) Iterations: [16, 11]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.831376 (450382.9162, 86402.6838) 11005.1981
# Finished plotting Isle of Wight.
# ==== County Durham (1 -> 1425) ====
# [0, 1425] (0, 1425)
# Analyzing best overall circle...  Iterations: [7, 6]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.831872 (408088.4486, 532764.5239) 26658.8664
# Finished plotting County Durham.
# ==== Cheshire East (1 -> 1847) ====
# [0, 1847] (0, 1847)
# Analyzing best overall circle...  Iterations: [14, 19]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.673247 (381271.9638, 369655.0715) 19265.8988
# Finished plotting Cheshire East.
# ==== Cheshire West and Chester (2 -> 1756) ====
# [0, 1752, 1756] (0, 1752)
# Analyzing best overall circle...  Iterations: [12, 11]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.749349 (352545.4888, 365586.9122) 17082.3755
# Finished plotting Cheshire West and Chester.
# ==== Shropshire (1 -> 3307) ====
# [0, 3307] (0, 3307)
# Analyzing best overall circle...  Iterations: [14, 18]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.796426 (352305.8053, 304515.8112) 31895.3277
# Finished plotting Shropshire.
# ==== Cornwall (33 -> 10873) ====
# [0, 10625, 10639, 10658, 10690, 10704, 10717, 10729, 10739, 10746, 10753, 10761, 10768, 10773, 10779, 10787, 10794, 10799, 10804, 10810, 10815, 10820, 10825, 10830, 10834, 10838, 10844, 10849, 10853, 10857, 10861, 10865, 10869, 10873] (0, 10625)
# Analyzing best overall circle...  Iterations: [19, 13]
# Analyzing best part circle... (1 out of 33) Iterations: [12, 16]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.648321 (210219.1539, 66622.3021) 33601.9938
# Finished plotting Cornwall.
# ==== Isles of Scilly (82 -> 1236) ====
# [0, 188, 288, 412, 532, 658, 681, 729, 755, 789, 814, 838, 853, 866, 878, 890, 903, 910, 919, 932, 940, 946, 952, 959, 964, 971, 979, 987, 996, 1005, 1011, 1016, 1021, 1029, 1034, 1040, 1045, 1049, 1054, 1059, 1063, 1067, 1071, 1076, 1081, 1085, 1090, 1094, 1098, 1104, 1108, 1112, 1116, 1120, 1124, 1128, 1132, 1136, 1140, 1144, 1148, 1152, 1156, 1160, 1164, 1168, 1172, 1176, 1180, 1184, 1188, 1192, 1196, 1200, 1204, 1208, 1212, 1216, 1220, 1224, 1228, 1232, 1236] (0, 188)
# Analyzing best overall circle...  Iterations: [15, 18]
# Analyzing best part circle... (1 out of 82) Iterations: [2, 3]
# Analyzing best part circle... (2 out of 82) Iterations: [19, 12]
# Analyzing best part circle... (3 out of 82) Iterations: [22, 11]
# Analyzing best part circle... (4 out of 82) Iterations: [5, 2]
# Analyzing best part circle... (5 out of 82) Iterations: [42, 16]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.401278 (91579.5324, 10915.3009) 2249.2678
# Finished plotting Isles of Scilly.
# ==== Wiltshire (1 -> 1684) ====
# [0, 1684] (0, 1684)
# Analyzing best overall circle...  Iterations: [13, 9]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.842085 (403585.4165, 153825.0633) 32206.8024
# Finished plotting Wiltshire.
# ==== South Tyneside (1 -> 282) ====
# [0, 282] (0, 282)
# Analyzing best overall circle...  Iterations: [14, 9]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.832928 (435553.2360, 563471.2095) 4528.0798
# Finished plotting South Tyneside.
# ==== Bedford (1 -> 499) ====
# [0, 499] (0, 499)
# Analyzing best overall circle...  Iterations: [11, 9]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.894386 (504211.6655, 255626.7340) 12316.7237
# Finished plotting Bedford.
# ==== Chiltern (1 -> 375) ====
# [0, 375] (0, 375)
# Analyzing best overall circle...  Iterations: [13, 12]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.840751 (494620.1366, 199134.4662) 7907.6396
# Finished plotting Chiltern.
# ==== Brent (1 -> 173) ====
# [0, 173] (0, 173)
# Analyzing best overall circle...  Iterations: [8, 16]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.832627 (519761.4544, 186198.7229) 3707.7137
# Finished plotting Brent.
# ==== Central Bedfordshire (1 -> 942) ====
# [0, 942] (0, 942)
# Analyzing best overall circle...  Iterations: [14, 11]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.700411 (505464.3087, 232110.6740) 15095.5166
# Finished plotting Central Bedfordshire.
# ==== Northumberland (27 -> 2875) ====
# [0, 2456, 2587, 2665, 2681, 2693, 2705, 2721, 2739, 2749, 2759, 2768, 2778, 2786, 2799, 2806, 2813, 2819, 2825, 2830, 2835, 2841, 2847, 2857, 2861, 2866, 2871, 2875] (0, 2456)
# Analyzing best overall circle...  Iterations: [14, 13]
# Analyzing best part circle... (1 out of 27) Iterations: [5, 8]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.806323 (396105.9059, 590367.3020) 40005.4535
# Finished plotting Northumberland.
# ==== Aylesbury Vale (1 -> 1229) ====
# [0, 1229] (0, 1229)
# Analyzing best overall circle...  Iterations: [12, 13]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.822958 (476841.3098, 221137.1363) 16955.3486
# Finished plotting Aylesbury Vale.
# ==== South Bucks (1 -> 404) ====
# [0, 404] (0, 404)
# Analyzing best overall circle...  Iterations: [14, 14]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.746779 (498351.9777, 185948.0846) 6706.8690
# Finished plotting South Bucks.
# ==== Wycombe (1 -> 499) ====
# [0, 499] (0, 499)
# Analyzing best overall circle...  Iterations: [17, 17]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.812971 (482203.5234, 194430.6770) 10169.2340
# Finished plotting Wycombe.
# ==== Cambridge (1 -> 158) ====
# [0, 158] (0, 158)
# Analyzing best overall circle...  Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.872372 (545710.9686, 257879.0180) 3600.2270
# Finished plotting Cambridge.
# ==== East Cambridgeshire (2 -> 702) ====
# [0, 607, 702] (0, 607)
# Analyzing best overall circle...  Iterations: [11, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [10, 14]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.742019 (554458.5208, 277009.0139) 14393.9895
# Finished plotting East Cambridgeshire.
# ==== Christchurch (4 -> 364) ====
# [0, 336, 352, 359, 364] (0, 336)
# Analyzing best overall circle...  Iterations: [17, 11]
# Analyzing best part circle... (1 out of 4) Iterations: [18, 13]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.633324 (414440.4004, 96095.9416) 4007.2999
# Finished plotting Christchurch.
# ==== Fenland (2 -> 447) ====
# [0, 351, 447] (0, 351)
# Analyzing best overall circle...  Iterations: [11, 14]
# Analyzing best part circle... (1 out of 2) Iterations: [11, 6]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.815080 (539198.9109, 296928.4902) 13192.1457
# Finished plotting Fenland.
# ==== Bolsover (1 -> 493) ====
# [0, 493] (0, 493)
# Analyzing best overall circle...  Iterations: [12, 13]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.660127 (449899.7719, 371874.3347) 7143.4577
# Finished plotting Bolsover.
# ==== Huntingdonshire (2 -> 893) ====
# [0, 889, 893] (0, 889)
# Analyzing best overall circle...  Iterations: [9, 12]
# Analyzing best part circle... (1 out of 2) Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.867675 (521326.8387, 276858.4313) 17047.9923
# Finished plotting Huntingdonshire.
# ==== Eastbourne (1 -> 138) ====
# [0, 138] (0, 138)
# Analyzing best overall circle...  Iterations: [12, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.756209 (559913.4629, 99849.9446) 3750.4245
# Finished plotting Eastbourne.
# ==== South Cambridgeshire (2 -> 1004) ====
# [0, 846, 1004] (0, 846)
# Analyzing best overall circle...  Iterations: [5, 9]
# Analyzing best part circle... (1 out of 2) Iterations: [5, 9]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.872260 (541058.5710, 255428.6370) 17691.0157
# Finished plotting South Cambridgeshire.
# ==== Allerdale (3 -> 1873) ====
# [0, 1860, 1869, 1873] (0, 1860)
# Analyzing best overall circle...  Iterations: [8, 14]
# Analyzing best part circle... (1 out of 3) Iterations: [8, 14]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.815942 (319574.2556, 535092.9668) 20017.0936
# Finished plotting Allerdale.
# ==== Barrow-in-Furness (4 -> 689) ====
# [0, 318, 674, 682, 689] (318, 674)
# Analyzing best overall circle...  Iterations: [8, 18]
# Analyzing best part circle... (1 out of 4) Iterations: [17, 23]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.692771 (321618.7459, 472190.9890) 4983.9061
# Finished plotting Barrow-in-Furness.
# ==== Carlisle (4 -> 1517) ====
# [0, 1502, 1508, 1513, 1517] (0, 1502)
# Analyzing best overall circle...  Iterations: [10, 9]
# Analyzing best part circle... (1 out of 4) Iterations: [10, 9]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.858451 (347717.8703, 564741.7674) 18188.0054
# Finished plotting Carlisle.
# ==== Copeland (3 -> 1337) ====
# [0, 1321, 1330, 1337] (0, 1321)
# Analyzing best overall circle...  Iterations: [16, 16]
# Analyzing best part circle... (1 out of 3) Iterations: [16, 16]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.736675 (309955.1811, 505714.8893) 15320.6094
# Finished plotting Copeland.
# ==== Chesterfield (1 -> 277) ====
# [0, 277] (0, 277)
# Analyzing best overall circle...  Iterations: [18, 9]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.793953 (439741.3565, 373247.4009) 4583.6697
# Finished plotting Chesterfield.
# ==== Derbyshire Dales (1 -> 1294) ====
# [0, 1294] (0, 1294)
# Analyzing best overall circle...  Iterations: [14, 11]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.691080 (420311.6226, 364991.9289) 15916.2637
# Finished plotting Derbyshire Dales.
# ==== Eden (1 -> 1133) ====
# [0, 1133] (0, 1133)
# Analyzing best overall circle...  Iterations: [19, 13]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.875777 (359112.4229, 525011.9376) 26192.2194
# Finished plotting Eden.
# ==== South Lakeland (3 -> 1991) ====
# [0, 1930, 1984, 1991] (0, 1930)
# Analyzing best overall circle...  Iterations: [10, 13]
# Analyzing best part circle... (1 out of 3) Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.811724 (342265.2483, 491037.8682) 22242.1084
# Finished plotting South Lakeland.
# ==== Amber Valley (1 -> 690) ====
# [0, 690] (0, 690)
# Analyzing best overall circle...  Iterations: [10, 9]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.846799 (436444.6494, 348520.1581) 9191.6693
# Finished plotting Amber Valley.
# ==== Erewash (1 -> 425) ====
# [0, 425] (0, 425)
# Analyzing best overall circle...  Iterations: [8, 17]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.735128 (444814.9669, 337161.4761) 5909.9620
# Finished plotting Erewash.
# ==== High Peak (1 -> 695) ====
# [0, 695] (0, 695)
# Analyzing best overall circle...  Iterations: [8, 11]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.800631 (408939.2289, 385707.0419) 13116.7455
# Finished plotting High Peak.
# ==== Exeter (1 -> 252) ====
# [0, 252] (0, 252)
# Analyzing best overall circle...  Iterations: [9, 9]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.915528 (293295.6459, 92693.8805) 3869.9535
# Finished plotting Exeter.
# ==== Mid Devon (1 -> 1236) ====
# [0, 1236] (0, 1236)
# Analyzing best overall circle...  Iterations: [9, 17]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.718509 (293578.8075, 110249.3858) 17049.2659
# Finished plotting Mid Devon.
# ==== North Devon (1 -> 1996) ====
# [0, 1996] (0, 1996)
# Analyzing best overall circle...  Iterations: [8, 11]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.797762 (267481.7679, 131927.0930) 18593.1017
# Finished plotting North Devon.
# ==== South Hams (5 -> 3189) ====
# [0, 3140, 3169, 3180, 3184, 3189] (0, 3140)
# Analyzing best overall circle...  Iterations: [8, 18]
# Analyzing best part circle... (1 out of 5) Iterations: [8, 18]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.847957 (270049.7434, 53882.8005) 16799.3514
# Finished plotting South Hams.
# ==== North East Derbyshire (1 -> 860) ====
# [0, 860] (0, 860)
# Analyzing best overall circle...  Iterations: [5, 14]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.691174 (437182.5570, 371687.9040) 9368.2523
# Finished plotting North East Derbyshire.
# ==== Hastings (1 -> 161) ====
# [0, 161] (0, 161)
# Analyzing best overall circle...  Iterations: [13, 10]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.765083 (580352.3574, 110932.6486) 3076.1433
# Finished plotting Hastings.
# ==== South Derbyshire (1 -> 976) ====
# [0, 976] (0, 976)
# Analyzing best overall circle...  Iterations: [19, 17]
# Fine-tuning the circle... Iterations: [8]
# Result info: 0.677060 (428344.4371, 326635.2721) 10374.4806
# Finished plotting South Derbyshire.
# ==== Southwark (1 -> 172) ====
# [0, 172] (0, 172)
# Analyzing best overall circle...  Iterations: [9, 16]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.694237 (533918.7068, 176852.0609) 3030.3039
# Finished plotting Southwark.
# ==== East Devon (1 -> 1108) ====
# [0, 1108] (0, 1108)
# Analyzing best overall circle...  Iterations: [7, 23]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.774136 (316175.1074, 96403.5349) 16099.0278
# Finished plotting East Devon.
# ==== Teignbridge (1 -> 1005) ====
# [0, 1005] (0, 1005)
# Analyzing best overall circle...  Iterations: [7, 10]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.917909 (282982.0431, 80052.4044) 14640.9120
# Finished plotting Teignbridge.
# ==== Torridge (4 -> 3124) ====
# [0, 2912, 3115, 3120, 3124] (0, 2912)
# Analyzing best overall circle...  Iterations: [17, 12]
# Analyzing best part circle... (1 out of 4) Iterations: [14, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.771660 (243242.7942, 111545.7120) 17714.1080
# Finished plotting Torridge.
# ==== West Devon (1 -> 1306) ====
# [0, 1306] (0, 1306)
# Analyzing best overall circle...  Iterations: [9, 8]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.862458 (255524.4878, 86287.6507) 19217.4057
# Finished plotting West Devon.
# ==== East Dorset (1 -> 623) ====
# [0, 623] (0, 623)
# Analyzing best overall circle...  Iterations: [9, 22]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.810014 (403468.6079, 107561.1018) 10624.7253
# Finished plotting East Dorset.
# ==== Basildon (2 -> 379) ====
# [0, 375, 379] (0, 375)
# Analyzing best overall circle...  Iterations: [15, 12]
# Analyzing best part circle... (1 out of 2) Iterations: [15, 12]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.842493 (570880.0275, 191102.7620) 5920.5560
# Finished plotting Basildon.
# ==== North Dorset (1 -> 725) ====
# [0, 725] (0, 725)
# Analyzing best overall circle...  Iterations: [10, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.868007 (382741.4328, 111842.8677) 13926.2069
# Finished plotting North Dorset.
# ==== Purbeck (15 -> 1351) ====
# [0, 1122, 1150, 1193, 1229, 1247, 1267, 1281, 1297, 1311, 1319, 1329, 1337, 1343, 1347, 1351] (0, 1122)
# Analyzing best overall circle...  Iterations: [15, 7]
# Analyzing best part circle... (1 out of 15) Iterations: [15, 7]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.830194 (389230.7923, 87552.7681) 11339.7160
# Finished plotting Purbeck.
# ==== West Dorset (1 -> 1393) ====
# [0, 1393] (0, 1393)
# Analyzing best overall circle...  Iterations: [14, 15]
# Fine-tuning the circle... Iterations: [13]
# Result info: 0.810437 (360757.3315, 98312.9009) 18557.4678
# Finished plotting West Dorset.
# ==== Weymouth and Portland (2 -> 315) ====
# [0, 172, 315] (0, 172)
# Analyzing best overall circle...  Iterations: [23, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [14, 14]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.535445 (367863.0640, 82179.6726) 3648.4939
# Finished plotting Weymouth and Portland.
# ==== Lewes (6 -> 847) ====
# [0, 798, 815, 832, 839, 843, 847] (0, 798)
# Analyzing best overall circle...  Iterations: [8, 16]
# Analyzing best part circle... (1 out of 6) Iterations: [19, 12]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.791385 (540787.6791, 112024.4734) 9643.6637
# Finished plotting Lewes.
# ==== Coventry (1 -> 231) ====
# [0, 231] (0, 231)
# Analyzing best overall circle...  Iterations: [9, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.893123 (432921.1674, 280043.1845) 5602.2606
# Finished plotting Coventry.
# ==== Rother (1 -> 875) ====
# [0, 875] (0, 875)
# Analyzing best overall circle...  Iterations: [15, 11]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.764960 (577153.7632, 119918.0906) 12769.5649
# Finished plotting Rother.
# ==== Wealden (1 -> 1379) ====
# [0, 1379] (0, 1379)
# Analyzing best overall circle...  Iterations: [16, 14]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.767230 (554835.7520, 121829.4659) 16299.9962
# Finished plotting Wealden.
# ==== Sutton (1 -> 183) ====
# [0, 183] (0, 183)
# Analyzing best overall circle...  Iterations: [9, 9]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.852834 (527231.0365, 164151.5295) 3736.4425
# Finished plotting Sutton.
# ==== Braintree (1 -> 962) ====
# [0, 962] (0, 962)
# Analyzing best overall circle...  Iterations: [7, 9]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.828234 (578941.7594, 230899.0719) 13950.8792
# Finished plotting Braintree.
# ==== Tower Hamlets (1 -> 180) ====
# [0, 180] (0, 180)
# Analyzing best overall circle...  Iterations: [13, 13]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.787797 (536210.9233, 181615.8309) 2510.4067
# Finished plotting Tower Hamlets.
# ==== Brentwood (1 -> 339) ====
# [0, 339] (0, 339)
# Analyzing best overall circle...  Iterations: [18, 7]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.848543 (559753.9671, 195900.2020) 6979.7088
# Finished plotting Brentwood.
# ==== Castle Point (11 -> 390) ====
# [0, 112, 319, 339, 349, 359, 367, 372, 376, 382, 386, 390] (112, 319)
# Analyzing best overall circle...  Iterations: [5, 15]
# Analyzing best part circle... (1 out of 11) Iterations: [17, 19]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.853796 (579254.5082, 186019.0828) 3785.9515
# Finished plotting Castle Point.
# ==== Fareham (1 -> 366) ====
# [0, 366] (0, 366)
# Analyzing best overall circle...  Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.757823 (453820.2396, 106749.1358) 4862.3605
# Finished plotting Fareham.
# ==== Chelmsford (2 -> 662) ====
# [0, 658, 662] (0, 658)
# Analyzing best overall circle...  Iterations: [12, 10]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 10]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.830032 (571586.6947, 206154.7911) 10443.0180
# Finished plotting Chelmsford.
# ==== Gosport (1 -> 222) ====
# [0, 222] (0, 222)
# Analyzing best overall circle...  Iterations: [9, 14]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.807675 (459079.7503, 101241.6385) 2841.3592
# Finished plotting Gosport.
# ==== Waltham Forest (1 -> 157) ====
# [0, 157] (0, 157)
# Analyzing best overall circle...  Iterations: [19, 12]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.755161 (537716.4256, 189590.5902) 3513.5351
# Finished plotting Waltham Forest.
# ==== Colchester (6 -> 1150) ====
# [0, 1004, 1115, 1125, 1138, 1145, 1150] (0, 1004)
# Analyzing best overall circle...  Iterations: [9, 17]
# Analyzing best part circle... (1 out of 6) Iterations: [8, 18]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.851194 (596175.6592, 223642.7600) 10293.4574
# Finished plotting Colchester.
# ==== Epping Forest (1 -> 580) ====
# [0, 580] (0, 580)
# Analyzing best overall circle...  Iterations: [15, 7]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.799309 (547520.4713, 203361.6978) 10386.8328
# Finished plotting Epping Forest.
# ==== Harlow (1 -> 147) ====
# [0, 147] (0, 147)
# Analyzing best overall circle...  Iterations: [9, 9]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.811318 (545241.6800, 209631.4862) 3116.9892
# Finished plotting Harlow.
# ==== Maldon (34 -> 2579) ====
# [0, 2000, 2048, 2126, 2264, 2286, 2339, 2363, 2381, 2393, 2401, 2414, 2425, 2433, 2441, 2447, 2459, 2468, 2478, 2486, 2493, 2500, 2509, 2515, 2523, 2528, 2533, 2541, 2546, 2554, 2562, 2567, 2571, 2575, 2579] (0, 2000)
# Analyzing best overall circle...  Iterations: [12, 18]
# Analyzing best part circle... (1 out of 34) Iterations: [12, 18]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.817288 (590860.3149, 205131.3372) 10688.3933
# Finished plotting Maldon.
# ==== Bromley (1 -> 358) ====
# [0, 358] (0, 358)
# Analyzing best overall circle...  Iterations: [15, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.848383 (543074.5309, 165465.9816) 6914.1332
# Finished plotting Bromley.
# ==== Rochford (6 -> 1076) ====
# [0, 730, 964, 1027, 1067, 1072, 1076] (0, 730)
# Analyzing best overall circle...  Iterations: [14, 15]
# Analyzing best part circle... (1 out of 6) Iterations: [17, 8]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.624250 (591355.1675, 191753.6240) 7344.3183
# Finished plotting Rochford.
# ==== Tendring (12 -> 1439) ====
# [0, 1139, 1222, 1288, 1321, 1338, 1347, 1369, 1402, 1408, 1417, 1433, 1439] (0, 1139)
# Analyzing best overall circle...  Iterations: [5, 16]
# Analyzing best part circle... (1 out of 12) Iterations: [5, 16]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.882325 (614425.1311, 223738.5361) 10365.2804
# Finished plotting Tendring.
# ==== Uttlesford (1 -> 784) ====
# [0, 784] (0, 784)
# Analyzing best overall circle...  Iterations: [10, 19]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.830287 (555951.9938, 229210.4031) 14280.8066
# Finished plotting Uttlesford.
# ==== Cheltenham (1 -> 196) ====
# [0, 196] (0, 196)
# Analyzing best overall circle...  Iterations: [21, 10]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.858685 (394697.4744, 222064.2182) 3849.8942
# Finished plotting Cheltenham.
# ==== Cotswold (1 -> 1603) ====
# [0, 1603] (0, 1603)
# Analyzing best overall circle...  Iterations: [10, 11]
# Fine-tuning the circle... Iterations: [8]
# Result info: 0.720580 (410073.2901, 213709.0212) 19245.0060
# Finished plotting Cotswold.
# ==== Forest of Dean (1 -> 864) ====
# [0, 864] (0, 864)
# Analyzing best overall circle...  Iterations: [6, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.605445 (365458.8349, 213019.2879) 12947.1247
# Finished plotting Forest of Dean.
# ==== Gloucester (1 -> 133) ====
# [0, 133] (0, 133)
# Analyzing best overall circle...  Iterations: [17, 12]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.848830 (383834.0757, 217001.8029) 3590.6421
# Finished plotting Gloucester.
# ==== Stroud (1 -> 879) ====
# [0, 879] (0, 879)
# Analyzing best overall circle...  Iterations: [15, 13]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.786736 (378926.9755, 203084.0798) 12107.5064
# Finished plotting Stroud.
# ==== Camden (1 -> 114) ====
# [0, 114] (0, 114)
# Analyzing best overall circle...  Iterations: [9, 16]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.772908 (527512.2157, 184942.6630) 2635.1327
# Finished plotting Camden.
# ==== Tewkesbury (1 -> 902) ====
# [0, 902] (0, 902)
# Analyzing best overall circle...  Iterations: [7, 16]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.694137 (393598.3587, 227301.1820) 11483.1524
# Finished plotting Tewkesbury.
# ==== Wandsworth (1 -> 161) ====
# [0, 161] (0, 161)
# Analyzing best overall circle...  Iterations: [11, 15]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.698363 (525830.8800, 174036.9387) 3301.9306
# Finished plotting Wandsworth.
# ==== Basingstoke and Deane (1 -> 663) ====
# [0, 663] (0, 663)
# Analyzing best overall circle...  Iterations: [7, 17]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.853391 (456461.7499, 152818.7998) 14208.6852
# Finished plotting Basingstoke and Deane.
# ==== Hart (1 -> 383) ====
# [0, 383] (0, 383)
# Analyzing best overall circle...  Iterations: [7, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.871036 (477161.0352, 154544.2326) 8280.3406
# Finished plotting Hart.
# ==== East Hampshire (1 -> 635) ====
# [0, 635] (0, 635)
# Analyzing best overall circle...  Iterations: [14, 20]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.809462 (473606.7738, 133042.0184) 12798.9238
# Finished plotting East Hampshire.
# ==== Eastleigh (1 -> 456) ====
# [0, 456] (0, 456)
# Analyzing best overall circle...  Iterations: [4, 17]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.657451 (447719.7734, 115843.4361) 5038.3103
# Finished plotting Eastleigh.
# ==== Havant (7 -> 631) ====
# [0, 251, 539, 559, 582, 610, 626, 631] (251, 539)
# Analyzing best overall circle...  Iterations: [9, 15]
# Analyzing best part circle... (1 out of 7) Iterations: [9, 9]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.654355 (470985.3194, 108286.2158) 4197.2293
# Finished plotting Havant.
# ==== New Forest (3 -> 1665) ====
# [0, 1621, 1642, 1665] (0, 1621)
# Analyzing best overall circle...  Iterations: [9, 15]
# Analyzing best part circle... (1 out of 3) Iterations: [9, 15]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.820391 (427056.0191, 106574.0817) 15483.8782
# Finished plotting New Forest.
# ==== Rushmoor (1 -> 198) ====
# [0, 198] (0, 198)
# Analyzing best overall circle...  Iterations: [12, 13]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.793973 (485953.7535, 153252.6451) 3524.6277
# Finished plotting Rushmoor.
# ==== Watford (1 -> 126) ====
# [0, 126] (0, 126)
# Analyzing best overall circle...  Iterations: [9, 16]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.791948 (510675.3097, 197788.0277) 2610.7979
# Finished plotting Watford.
# ==== Test Valley (2 -> 830) ====
# [0, 810, 830] (0, 810)
# Analyzing best overall circle...  Iterations: [13, 14]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.729102 (434070.2705, 136986.3411) 14134.8401
# Finished plotting Test Valley.
# ==== Burnley (1 -> 288) ====
# [0, 288] (0, 288)
# Analyzing best overall circle...  Iterations: [14, 10]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.820892 (385956.5920, 431149.7946) 5936.5046
# Finished plotting Burnley.
# ==== Winchester (1 -> 792) ====
# [0, 792] (0, 792)
# Analyzing best overall circle...  Iterations: [9, 10]
# Fine-tuning the circle... Iterations: [9]
# Result info: 0.792676 (453444.3024, 127348.4804) 14498.6410
# Finished plotting Winchester.
# ==== Broxbourne (1 -> 147) ====
# [0, 147] (0, 147)
# Analyzing best overall circle...  Iterations: [18, 11]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.741947 (534567.2696, 203959.9081) 4047.6133
# Finished plotting Broxbourne.
# ==== Westminster (1 -> 130) ====
# [0, 130] (0, 130)
# Analyzing best overall circle...  Iterations: [11, 16]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.765048 (527947.9404, 181015.6323) 2614.0300
# Finished plotting Westminster.
# ==== Dacorum (1 -> 438) ====
# [0, 438] (0, 438)
# Analyzing best overall circle...  Iterations: [19, 15]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.752789 (501496.5842, 209360.3428) 8223.8212
# Finished plotting Dacorum.
# ==== Hertsmere (1 -> 279) ====
# [0, 279] (0, 279)
# Analyzing best overall circle...  Iterations: [6, 12]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.757555 (518626.0517, 199525.4205) 5671.9380
# Finished plotting Hertsmere.
# ==== Hyndburn (1 -> 196) ====
# [0, 196] (0, 196)
# Analyzing best overall circle...  Iterations: [9, 8]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.897869 (374386.4112, 429245.9873) 4818.8189
# Finished plotting Hyndburn.
# ==== Lancaster (11 -> 2150) ====
# [0, 2062, 2094, 2104, 2114, 2121, 2126, 2131, 2137, 2142, 2146, 2150] (0, 2062)
# Analyzing best overall circle...  Iterations: [12, 10]
# Analyzing best part circle... (1 out of 11) Iterations: [12, 10]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.835654 (354833.3696, 464144.8936) 13547.2037
# Finished plotting Lancaster.
# ==== North Hertfordshire (1 -> 724) ====
# [0, 724] (0, 724)
# Analyzing best overall circle...  Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.673191 (521059.5945, 228668.8313) 10932.3261
# Finished plotting North Hertfordshire.
# ==== Three Rivers (1 -> 305) ====
# [0, 305] (0, 305)
# Analyzing best overall circle...  Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.707916 (506100.8022, 196186.5684) 5316.3031
# Finished plotting Three Rivers.
# ==== Ashford (1 -> 706) ====
# [0, 706] (0, 706)
# Analyzing best overall circle...  Iterations: [8, 10]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.840608 (596274.4036, 138910.8825) 13597.6251
# Finished plotting Ashford.
# ==== Pendle (1 -> 344) ====
# [0, 344] (0, 344)
# Analyzing best overall circle...  Iterations: [8, 10]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.809099 (387385.3680, 441473.6159) 7342.1998
# Finished plotting Pendle.
# ==== Canterbury (3 -> 584) ====
# [0, 566, 576, 584] (0, 566)
# Analyzing best overall circle...  Iterations: [12, 16]
# Analyzing best part circle... (1 out of 3) Iterations: [12, 16]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.847766 (616603.4152, 158369.4202) 9916.8416
# Finished plotting Canterbury.
# ==== Dartford (1 -> 298) ====
# [0, 298] (0, 298)
# Analyzing best overall circle...  Iterations: [10, 14]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.790320 (556934.3845, 172730.7042) 4811.8703
# Finished plotting Dartford.
# ==== Dover (3 -> 608) ====
# [0, 532, 595, 608] (0, 532)
# Analyzing best overall circle...  Iterations: [9, 18]
# Analyzing best part circle... (1 out of 3) Iterations: [9, 18]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.826520 (629170.4702, 150714.8141) 10015.6033
# Finished plotting Dover.
# ==== Gravesham (1 -> 272) ====
# [0, 272] (0, 272)
# Analyzing best overall circle...  Iterations: [9, 13]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.771538 (566763.4622, 169849.3490) 5613.5779
# Finished plotting Gravesham.
# ==== Maidstone (1 -> 624) ====
# [0, 624] (0, 624)
# Analyzing best overall circle...  Iterations: [6, 15]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.885507 (579576.2808, 151529.8594) 11186.0722
# Finished plotting Maidstone.
# ==== Preston (3 -> 343) ====
# [0, 315, 336, 343] (0, 315)
# Analyzing best overall circle...  Iterations: [9, 12]
# Analyzing best part circle... (1 out of 3) Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.850046 (353979.5295, 435127.7863) 6731.0214
# Finished plotting Preston.
# ==== Sevenoaks (1 -> 714) ====
# [0, 714] (0, 714)
# Analyzing best overall circle...  Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.689004 (550764.3127, 151528.9755) 10858.1528
# Finished plotting Sevenoaks.
# ==== Welwyn Hatfield (1 -> 369) ====
# [0, 369] (0, 369)
# Analyzing best overall circle...  Iterations: [7, 15]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.721658 (525170.5830, 208686.6739) 6418.2260
# Finished plotting Welwyn Hatfield.
# ==== Shepway (1 -> 548) ====
# [0, 548] (0, 548)
# Analyzing best overall circle...  Iterations: [9, 17]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.555250 (613880.7111, 137999.3644) 10659.7833
# Finished plotting Shepway.
# ==== Swale (7 -> 1455) ====
# [0, 927, 1279, 1357, 1415, 1431, 1445, 1455] (0, 927)
# Analyzing best overall circle...  Iterations: [11, 10]
# Analyzing best part circle... (1 out of 7) Iterations: [11, 15]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.843364 (596454.8931, 162965.2010) 10914.1747
# Finished plotting Swale.
# ==== Thanet (2 -> 276) ====
# [0, 272, 276] (0, 272)
# Analyzing best overall circle...  Iterations: [13, 14]
# Analyzing best part circle... (1 out of 2) Iterations: [13, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.752818 (633578.3288, 167253.8800) 5734.9247
# Finished plotting Thanet.
# ==== Tonbridge and Malling (2 -> 725) ====
# [0, 549, 725] (0, 549)
# Analyzing best overall circle...  Iterations: [7, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [9, 10]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.760323 (565127.8574, 155335.8146) 8742.0242
# Finished plotting Tonbridge and Malling.
# ==== Croydon (1 -> 294) ====
# [0, 294] (0, 294)
# Analyzing best overall circle...  Iterations: [8, 15]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.756929 (533332.4467, 163661.0079) 5248.5327
# Finished plotting Croydon.
# ==== Tunbridge Wells (1 -> 968) ====
# [0, 968] (0, 968)
# Analyzing best overall circle...  Iterations: [16, 10]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.656048 (573944.0138, 137123.9882) 10272.7226
# Finished plotting Tunbridge Wells.
# ==== Chorley (3 -> 612) ====
# [0, 571, 608, 612] (0, 571)
# Analyzing best overall circle...  Iterations: [13, 13]
# Analyzing best part circle... (1 out of 3) Iterations: [13, 13]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.782374 (358176.7921, 418996.1976) 8035.0947
# Finished plotting Chorley.
# ==== Fylde (1 -> 530) ====
# [0, 530] (0, 530)
# Analyzing best overall circle...  Iterations: [7, 12]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.863747 (340317.2232, 432966.0805) 7261.9851
# Finished plotting Fylde.
# ==== Ribble Valley (1 -> 662) ====
# [0, 662] (0, 662)
# Analyzing best overall circle...  Iterations: [11, 13]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.885530 (371017.6427, 446083.7793) 13645.2571
# Finished plotting Ribble Valley.
# ==== Rossendale (1 -> 270) ====
# [0, 270] (0, 270)
# Analyzing best overall circle...  Iterations: [12, 20]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.835963 (382793.3506, 421816.1864) 6630.2287
# Finished plotting Rossendale.
# ==== South Ribble (1 -> 509) ====
# [0, 509] (0, 509)
# Analyzing best overall circle...  Iterations: [14, 10]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.706703 (351507.4123, 424923.4660) 5997.3060
# Finished plotting South Ribble.
# ==== Blaby (1 -> 545) ====
# [0, 545] (0, 545)
# Analyzing best overall circle...  Iterations: [11, 12]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.722489 (452103.7768, 297378.8832) 6445.3447
# Finished plotting Blaby.
# ==== West Lancashire (2 -> 859) ====
# [0, 855, 859] (0, 855)
# Analyzing best overall circle...  Iterations: [5, 11]
# Analyzing best part circle... (1 out of 2) Iterations: [5, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.815102 (342767.6941, 410339.3066) 10508.6661
# Finished plotting West Lancashire.
# ==== Ealing (1 -> 206) ====
# [0, 206] (0, 206)
# Analyzing best overall circle...  Iterations: [13, 14]
# Fine-tuning the circle... Iterations: [9]
# Result info: 0.783286 (515309.3175, 181751.2880) 4204.5191
# Finished plotting Ealing.
# ==== Wyre (16 -> 1094) ====
# [0, 787, 994, 1006, 1015, 1029, 1040, 1046, 1052, 1059, 1065, 1071, 1076, 1082, 1086, 1090, 1094] (0, 787)
# Analyzing best overall circle...  Iterations: [11, 13]
# Analyzing best part circle... (1 out of 16) Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.730810 (345908.6711, 445890.2206) 9477.2112
# Finished plotting Wyre.
# ==== Charnwood (1 -> 575) ====
# [0, 575] (0, 575)
# Analyzing best overall circle...  Iterations: [8, 17]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.832119 (456939.8829, 316467.7615) 9422.0304
# Finished plotting Charnwood.
# ==== Hinckley and Bosworth (1 -> 526) ====
# [0, 526] (0, 526)
# Analyzing best overall circle...  Iterations: [7, 17]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.833695 (440630.8556, 302600.6966) 9731.7351
# Finished plotting Hinckley and Bosworth.
# ==== Harborough (1 -> 1188) ====
# [0, 1188] (0, 1188)
# Analyzing best overall circle...  Iterations: [10, 20]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.710201 (470465.6198, 295613.8653) 13737.4500
# Finished plotting Harborough.
# ==== Melton (1 -> 698) ====
# [0, 698] (0, 698)
# Analyzing best overall circle...  Iterations: [13, 15]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.865298 (476952.4272, 321248.4594) 12383.9691
# Finished plotting Melton.
# ==== Corby (1 -> 363) ====
# [0, 363] (0, 363)
# ...
# Analyzing best overall circle...  Iterations: [14, 20]
# Analyzing best part circle... (1 out of 683) Iterations: [19, 14]
# Fine-tuning the circle... Iterations: [12]
# Result info: 0.522290 (435107.6396, 1163774.2986) 21625.7254
# Finished plotting Shetland Islands.
# ==== South Ayrshire (5 -> 1939) ====
# [0, 1877, 1897, 1923, 1933, 1939] (0, 1877)
# Analyzing best overall circle...  Iterations: [15, 12]
# Analyzing best part circle... (1 out of 5) Iterations: [10, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.698520 (226015.7674, 594908.1401) 19730.3948
# Finished plotting South Ayrshire.
# ==== South Lanarkshire (1 -> 1223) ====
# [0, 1223] (0, 1223)
# Analyzing best overall circle...  Iterations: [11, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.792374 (285858.1731, 638775.0540) 23761.1100
# Finished plotting South Lanarkshire.
# ==== Stirling (1 -> 1481) ====
# [0, 1481] (0, 1481)
# Analyzing best overall circle...  Iterations: [17, 20]
# Fine-tuning the circle... Iterations: [6]
# Result info: 0.800365 (259362.5791, 708140.7675) 26786.3596
# Finished plotting Stirling.
# ==== Aberdeen City (12 -> 700) ====
# [0, 654, 658, 663, 668, 672, 676, 680, 684, 688, 692, 696, 700] (0, 654)
# Analyzing best overall circle...  Iterations: [8, 18]
# Analyzing best part circle... (1 out of 12) Iterations: [8, 18]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.786833 (389541.8013, 808130.2029) 7684.9705
# Finished plotting Aberdeen City.
# ==== Aberdeenshire (98 -> 5169) ====
# [0, 4714, 4732, 4745, 4750, 4755, 4762, 4770, 4776, 4782, 4787, 4791, 4796, 4801, 4807, 4813, 4818, 4823, 4829, 4833, 4838, 4844, 4849, 4853, 4857, 4862, 4868, 4873, 4879, 4883, 4888, 4893, 4897, 4901, 4906, 4910, 4915, 4919, 4923, 4928, 4933, 4937, 4941, 4945, 4949, 4953, 4957, 4961, 4966, 4971, 4975, 4979, 4983, 4988, 4992, 4996, 5000, 5004, 5008, 5012, 5016, 5021, 5025, 5029, 5033, 5037, 5041, 5045, 5049, 5053, 5057, 5061, 5065, 5069, 5073, 5077, 5081, 5085, 5089, 5093, 5097, 5101, 5105, 5109, 5113, 5117, 5121, 5125, 5129, 5133, 5137, 5141, 5145, 5149, 5153, 5157, 5161, 5165, 5169] (0, 4714)
# Analyzing best overall circle...  Iterations: [13, 20]
# Analyzing best part circle... (1 out of 98) Iterations: [13, 20]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.752174 (369273.2570, 821095.7928) 44843.2922
# Finished plotting Aberdeenshire.
# ==== Argyll and Bute (743 -> 31465) ====
# [0, 7593, 11841, 15078, 16759, 17817, 18353, 19412, 20682, 21525, 21830, 22165, 22436, 22692, 23225, 23602, 23876, 24120, 24298, 24439, 24554, 24625, 24779, 24834, 24944, 25005, 25039, 25084, 25115, 25170, 25221, 25261, 25316, 25370, 25457, 25524, 25561, 25619, 25634, 25690, 25708, 25735, 25784, 25828, 25874, 25904, 25956, 26007, 26055, 26091, 26118, 26176, 26208, 26254, 26279, 26316, 26344, 26369, 26389, 26404, 26428, 26454, 26484, 26505, 26524, 26542, 26590, 26615, 26645, 26659, 26698, 26722, 26737, 26746, 26760, 26778, 26803, 26814, 26826, 26839, 26860, 26877, 26896, 26906, 26919, 26933, 26944, 26966, 26992, 27006, 27027, 27042, 27056, 27071, 27087, 27111, 27131, 27152, 27168, 27185, 27199, 27214, 27222, 27239, 27254, 27277, 27289, 27303, 27312, 27328, 27344, 27351, 27362, 27378, 27397, 27408, 27427, 27439, 27455, 27480, 27490, 27500, 27515, 27526, 27541, 27557, 27569, 27583, 27593, 27608, 27626, 27638, 27656, 27666, 27680, 27688, 27702, 27714, 27730, 27748, 27755, 27761, 27769, 27777, 27791, 27808, 27819, 27839, 27850, 27857, 27866, 27880, 27891, 27904, 27918, 27927, 27937, 27946, 27958, 27970, 27982, 27998, 28006, 28018, 28029, 28040, 28047, 28057, 28066, 28088, 28099, 28112, 28120, 28127, 28137, 28144, 28151, 28164, 28172, 28180, 28194, 28202, 28216, 28223, 28233, 28242, 28249, 28259, 28267, 28277, 28284, 28292, 28307, 28318, 28329, 28338, 28348, 28354, 28368, 28381, 28394, 28404, 28415, 28422, 28431, 28439, 28450, 28465, 28474, 28484, 28498, 28507, 28513, 28518, 28524, 28532, 28542, 28549, 28556, 28564, 28574, 28584, 28598, 28609, 28619, 28627, 28635, 28642, 28650, 28658, 28664, 28675, 28682, 28690, 28696, 28705, 28712, 28721, 28734, 28741, 28747, 28757, 28767, 28775, 28782, 28791, 28798, 28809, 28818, 28829, 28835, 28846, 28855, 28866, 28874, 28880, 28887, 28892, 28898, 28909, 28919, 28925, 28933, 28939, 28945, 28954, 28964, 28970, 28980, 28987, 28992, 28998, 29003, 29012, 29020, 29026, 29032, 29038, 29044, 29052, 29057, 29062, 29069, 29076, 29088, 29097, 29105, 29111, 29121, 29127, 29133, 29139, 29148, 29153, 29159, 29166, 29171, 29176, 29183, 29189, 29196, 29207, 29213, 29222, 29229, 29242, 29247, 29254, 29260, 29266, 29271, 29276, 29283, 29288, 29293, 29299, 29308, 29314, 29323, 29332, 29339, 29348, 29353, 29361, 29369, 29377, 29385, 29391, 29396, 29404, 29409, 29414, 29420, 29425, 29432, 29438, 29444, 29451, 29460, 29467, 29473, 29479, 29485, 29493, 29498, 29504, 29511, 29518, 29524, 29531, 29536, 29543, 29550, 29555, 29565, 29571, 29576, 29582, 29588, 29593, 29600, 29607, 29612, 29619, 29629, 29634, 29638, 29644, 29649, 29657, 29661, 29671, 29678, 29684, 29690, 29699, 29707, 29713, 29721, 29727, 29732, 29737, 29742, 29747, 29754, 29761, 29766, 29772, 29776, 29785, 29790, 29798, 29803, 29811, 29816, 29824, 29829, 29834, 29840, 29845, 29851, 29858, 29864, 29869, 29874, 29881, 29886, 29892, 29898, 29904, 29910, 29916, 29921, 29926, 29932, 29937, 29942, 29947, 29952, 29957, 29962, 29967, 29972, 29978, 29984, 29989, 29995, 30000, 30005, 30014, 30023, 30028, 30033, 30038, 30043, 30049, 30054, 30059, 30064, 30069, 30074, 30079, 30085, 30090, 30095, 30101, 30105, 30110, 30114, 30120, 30125, 30130, 30135, 30140, 30145, 30153, 30157, 30163, 30168, 30173, 30178, 30185, 30190, 30195, 30200, 30205, 30209, 30214, 30219, 30225, 30229, 30234, 30238, 30243, 30250, 30256, 30263, 30268, 30273, 30278, 30283, 30290, 30295, 30301, 30305, 30310, 30315, 30320, 30325, 30331, 30336, 30341, 30345, 30351, 30355, 30361, 30366, 30371, 30375, 30380, 30384, 30389, 30394, 30401, 30406, 30412, 30417, 30422, 30427, 30431, 30436, 30443, 30449, 30454, 30458, 30465, 30473, 30477, 30482, 30487, 30493, 30498, 30504, 30510, 30516, 30521, 30526, 30532, 30537, 30542, 30547, 30553, 30558, 30562, 30566, 30571, 30575, 30580, 30589, 30595, 30599, 30603, 30608, 30612, 30616, 30620, 30625, 30630, 30636, 30640, 30644, 30648, 30653, 30657, 30661, 30667, 30671, 30676, 30680, 30685, 30690, 30694, 30699, 30705, 30710, 30715, 30719, 30724, 30729, 30734, 30738, 30742,  ...
# Analyzing best overall circle...  Iterations: [12, 12]
# Analyzing best part circle... (1 out of 743) Iterations: [13, 12]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.635862 (192812.2864, 704579.5429) 47233.4377
# Finished plotting Argyll and Bute.
# ==== City of Edinburgh (4 -> 472) ====
# [0, 446, 460, 467, 472] (0, 446)
# Analyzing best overall circle...  Iterations: [13, 10]
# Analyzing best part circle... (1 out of 4) Iterations: [13, 7]
# Fine-tuning the circle... Iterations: [7]
# Result info: 0.797291 (319585.1148, 671248.5741) 9160.9938
# Finished plotting City of Edinburgh.
# ==== West Dunbartonshire (1 -> 500) ====
# [0, 500] (0, 500)
# Analyzing best overall circle...  Iterations: [12, 13]
# Fine-tuning the circle... Iterations: [11]
# Result info: 0.765906 (242838.9019, 681083.7017) 7510.9702
# Finished plotting West Dunbartonshire.
# ==== Renfrewshire (1 -> 671) ====
# [0, 671] (0, 671)
# Analyzing best overall circle...  Iterations: [16, 15]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.809898 (241772.1925, 664456.7639) 9124.9410
# Finished plotting Renfrewshire.
# ==== East Dunbartonshire (1 -> 452) ====
# [0, 452] (0, 452)
# Analyzing best overall circle...  Iterations: [6, 15]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.759923 (260596.3129, 676050.2557) 7455.8860
# Finished plotting East Dunbartonshire.
# ==== West Lothian (1 -> 623) ====
# [0, 623] (0, 623)
# Analyzing best overall circle...  Iterations: [11, 8]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.881072 (301570.4193, 666712.0001) 11688.8030
# Finished plotting West Lothian.
# ==== Angus (2 -> 1422) ====
# [0, 1416, 1422] (0, 1416)
# Analyzing best overall circle...  Iterations: [4, 11]
# Analyzing best part circle... (1 out of 2) Iterations: [4, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.891121 (344547.1714, 760004.9095) 26366.7120
# Finished plotting Angus.
# ==== Dundee City (1 -> 187) ====
# [0, 187] (0, 187)
# Analyzing best overall circle...  Iterations: [15, 15]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.661115 (339242.4082, 732094.9215) 4364.6079
# Finished plotting Dundee City.
# ==== North Lanarkshire (1 -> 740) ====
# [0, 740] (0, 740)
# Analyzing best overall circle...  Iterations: [12, 15]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.793356 (279877.6800, 665002.0119) 12265.5070
# Finished plotting North Lanarkshire.
# ==== Glasgow City (2 -> 643) ====
# [0, 399, 643] (0, 399)
# Analyzing best overall circle...  Iterations: [8, 14]
# Analyzing best part circle... (1 out of 2) Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.776580 (258576.2547, 664567.9551) 7454.5862
# Finished plotting Glasgow City.
# ==== Isle of Anglesey (31 -> 2931) ====
# [0, 1862, 2722, 2733, 2749, 2760, 2777, 2785, 2800, 2814, 2820, 2825, 2832, 2838, 2843, 2849, 2855, 2863, 2871, 2876, 2881, 2886, 2891, 2895, 2899, 2904, 2909, 2914, 2918, 2923, 2927, 2931] (0, 1862)
# Analyzing best overall circle...  Iterations: [9, 12]
# Analyzing best part circle... (1 out of 31) Iterations: [14, 14]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.861584 (241580.6306, 379208.8885) 15087.8150
# Finished plotting Isle of Anglesey.
# ==== Gwynedd (14 -> 3081) ====
# [0, 2892, 2992, 3006, 3016, 3025, 3034, 3042, 3050, 3057, 3062, 3066, 3072, 3077, 3081] (0, 2892)
# Analyzing best overall circle...  Iterations: [19, 15]
# Analyzing best part circle... (1 out of 14) Iterations: [20, 11]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.677128 (266694.7040, 333957.5136) 28498.1318
# Finished plotting Gwynedd.
# ==== Conwy (1 -> 1172) ====
# [0, 1172] (0, 1172)
# Analyzing best overall circle...  Iterations: [9, 14]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.885555 (283736.1679, 361806.4046) 18969.0642
# Finished plotting Conwy.
# ==== Bridgend (1 -> 428) ====
# [0, 428] (0, 428)
# Analyzing best overall circle...  Iterations: [10, 11]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.855962 (289382.9595, 186056.9368) 8933.1453
# Finished plotting Bridgend.
# ==== Denbighshire (2 -> 979) ====
# [0, 975, 979] (0, 975)
# Analyzing best overall circle...  Iterations: [16, 11]
# Analyzing best part circle... (1 out of 2) Iterations: [16, 11]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.749615 (309186.6777, 351404.4488) 16329.2849
# Finished plotting Denbighshire.
# ==== Flintshire (7 -> 930) ====
# [0, 708, 889, 902, 909, 918, 924, 930] (0, 708)
# Analyzing best overall circle...  Iterations: [12, 12]
# Analyzing best part circle... (1 out of 7) Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [4]
# Result info: 0.752574 (324412.4836, 366262.3083) 11801.8536
# Finished plotting Flintshire.
# ==== Wrexham (1 -> 995) ====
# [0, 995] (0, 995)
# Analyzing best overall circle...  Iterations: [16, 12]
# Fine-tuning the circle... Iterations: [2]
# Result info: 0.689202 (335829.3037, 346344.0594) 12662.4788
# Finished plotting Wrexham.
# ==== Ceredigion (5 -> 2282) ====
# [0, 2162, 2248, 2269, 2277, 2282] (0, 2162)
# Analyzing best overall circle...  Iterations: [10, 16]
# Analyzing best part circle... (1 out of 5) Iterations: [10, 16]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.704930 (262834.1042, 269107.6618) 23859.6732
# Finished plotting Ceredigion.
# ==== Pembrokeshire (55 -> 6361) ====
# [0, 5486, 5628, 5787, 5884, 5997, 6019, 6035, 6051, 6068, 6096, 6115, 6122, 6137, 6153, 6165, 6173, 6181, 6188, 6197, 6202, 6208, 6215, 6221, 6227, 6232, 6237, 6242, 6248, 6253, 6258, 6263, 6268, 6273, 6277, 6281, 6285, 6289, 6293, 6297, 6301, 6305, 6309, 6313, 6317, 6321, 6325, 6329, 6333, 6337, 6341, 6345, 6349, 6353, 6357, 6361] (0, 5486)
# Analyzing best overall circle...  Iterations: [11, 23]
# Analyzing best part circle... (1 out of 55) Iterations: [10, 19]
# Fine-tuning the circle... Iterations: [5]
# Result info: 0.801676 (198652.9497, 218750.0989) 22688.0521
# Finished plotting Pembrokeshire.
# ==== Carmarthenshire (10 -> 3892) ====
# [0, 3457, 3610, 3688, 3769, 3796, 3816, 3837, 3858, 3878, 3892] (0, 3457)
# Analyzing best overall circle...  Iterations: [10, 10]
# Analyzing best part circle... (1 out of 10) Iterations: [10, 10]
# Fine-tuning the circle... Iterations: [3]
# Result info: 0.809819 (251884.8279, 225316.1859) 27466.4624
# Finished plotting Carmarthenshire.
# ==== Swansea (26 -> 2309) ====
# [0, 2112, 2134, 2161, 2177, 2190, 2201, 2209, 2216, 2221, 2227, 2234, 2240, 2246, 2254, 2260, 2265, 2270, 2275, 2279, 2284, 2288, 2292, 2296, 2300, 2305, 2309] (0, 2112)
# Analyzing best overall circle...  Iterations: [13,

# %%
import base64
import io
import math
import operator
import random
import time
import urllib

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
import rtree

# %%
import shapefile

# %%
from shapely.geometry import Polygon, Point

# %%
import pyproj

# %%
def slice_at(plist, indices):
    '''
    Slices the list ll at the indices indicated.
    '''
    indices.append(len(plist))
    for fro, to in zip(indices, indices[1:]):
        yield plist[fro:to]

# %%
def plot_country(name, parts, center, radius):
    fig, ax = plt.subplots(figsize=(1.8, 1.8))

    circle = plt.Circle(center, radius, color='k', fill=False)
    for part in parts:
        #color = random.choice('bgrcmk')
        color = 'k'
        for point1, point2 in zip(part, part[1:]):
            ax.plot(
                [point1[0], point2[0]],
                [point1[1], point2[1]],
                color+'-')
    ax.add_artist(circle)
    ax.set_aspect('equal', 'datalim')
    imgdata = io.BytesIO()
    #ax.set_title(name)
    plt.axis('off')
    #plt.savefig(name.lower().replace(' ', '-') + '.png', transparent=True)
    #plt.show()
    plt.savefig('tmp.png', format='png', transparent=True)
    img = Image.open('tmp.png')
    png_info = img.info
    img.convert('P').save(imgdata, 'PNG', **png_info)
    imgdata.seek(0)
    plt.close(fig)
    return imgdata

# %%
def neighbours(center, radius, delta):
    cmov = delta
    rmov = delta
    cms = [cmov*20, cmov, 0, -cmov, -cmov*20]
    rms = [rmov*20, rmov, 0, -rmov, -rmov*20]
    for cx_mov in cms:
        for cy_mov in cms:
            for r_mov in rms:
                if radius + r_mov > 0:
                    yield ((center[0] + cx_mov, center[1] + cy_mov),
                           radius + r_mov)

# %%
def maxmin(arr):
    _max = arr[0]
    _min = arr[0]
    for x in arr:
        if x > _max:
            _max = x
        elif x < _min:
            _min = x
    return _max, _min

# %%
def heuristic(polygons, index, c, r, delta, iters=200):
    best_coeff = 0
    parts_area = sum(map(lambda x: x.area, polygons))
    is_ = 0
    for _ in range(iters):
        is_ += 1
        mejoro = False
        for c_, r_ in neighbours(c, r, delta):
            circle = Point(c_).buffer(r_)
            indices = range(len(polygons))
            if circle.bounds != ():
                indices = [int(i) for i in index.intersection(circle.bounds)]
            else:
                print('WARNING: circle.bounds == (). '\
                      'center = %s, radius = %.3f' % (str(c_), r_))
            intersection_area = sum(
                [polygons[i].intersection(circle).area for i in indices])
            coeff = intersection_area / max(math.pi * r_ * r_, parts_area)
            #print(c_, r_)
            #print(intersection_area, circle_area, parts_area)
            if coeff > best_coeff:
                mejoro = True
                c = c_
                r = r_
                best_coeff = coeff
        if not mejoro:
            break
    return c, r, best_coeff, is_

# %%
def circle_inside(xmin, ymin, xmax, ymax):
    center = [(xmin + xmax) / 2, (ymin + ymax) / 2]
    radius = min((xmax - xmin) / 2, (ymax - ymin) / 2)
    return center, radius

# %%
def circle_outside(xmin, ymin, xmax, ymax):
    center = [(xmin + xmax) / 2, (ymin + ymax) / 2]
    radius = math.sqrt((xmax - xmin)**2.0 + (ymax - ymin)**2.0) / 2
    return center, radius

# %%
def analyze_both_circles(polys, index, min_x, min_y, max_x, max_y):
    cinside, rinside = circle_inside(min_x, min_y, max_x, max_y)
    coutside, routside = circle_outside(min_x, min_y, max_x, max_y)
    c_i, r_i, best_i, iin = heuristic(
        polys, index, cinside, rinside, rinside / 200)
    print('[%d, ' % iin, end='', flush=True)
    c_o, r_o, best_o, iout = heuristic(
        polys, index, coutside, routside, routside / 200)
    print('%d]' % iout)
    best_coeff_ = max(best_i, best_o)
    center_ = c_i if best_i > best_o else c_o
    radius_ = r_i if best_i > best_o else r_o
    return center_, radius_, best_coeff_

# %%
def find_best_circle(parts, minx, miny, maxx, maxy):
    polys = [Polygon(part).buffer(0) for part in parts]
    index = rtree.index.Index()
    for i, poly in enumerate(polys):
        index.insert(i, poly.bounds)
    print('Analyzing best overall circle...  Iterations: ', end='', flush=True)
    c, r, best_coeff = analyze_both_circles(
        polys, index, minx, miny, maxx, maxy)
    best_polygons = []
    if len(polys) > 1:
        polygons_area = sorted(
            [(poly, poly.area) for poly in polys],
            key=lambda x: x[1], reverse=True)
        areas = list(map(lambda r: r[1], polygons_area))
        if areas[0] > sum(areas[1:]):
            best_polygons = [polygons_area[0][0]]
        else:
            best_polygons = list(map(lambda x: x[0], polygons_area))[:5]
    i = 0
    for part in best_polygons:
        if len(polys) == 1:
            break
        i += 1
        print('Analyzing best part circle... (%d out of %d) Iterations: ' \
            % (i, len(polys)), end='', flush=True)
        x, y = part.exterior.coords.xy
        max_x, min_x = maxmin(x)
        max_y, min_y = maxmin(y)
        center_, radius_, best_coeff_ = analyze_both_circles(
            polys, index, min_x, min_y, max_x, max_y)
        if best_coeff_ > best_coeff:
            c = center_
            r = radius_
            best_coeff = best_coeff_
    # fine tune it.
    print('Fine-tuning the circle... Iterations: ', end='', flush=True)
    c, r, best_coeff, iters = heuristic(polys, index, c, r, r / 1000, 1000)
    print('[%d]' % iters)
    return c, r, best_coeff

# %%
def tuple2list(t):
    t = tuple(t)[0]
    return [t[0], t[1]]

# %%
def concat(ls):
    return [j for i in ls for j in i]

# %%
def mean(ls):
    return float(sum(ls)) / len(ls)

# %%
INPUT_FILE = 'ne_10m_admin_0_sovereignty'
FROM_PROJ = '+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs'

# %%
fields =shapefile.Reader(INPUT_FILE).fields[1:] 
field_names = [field[0] for field in fields] 
# construction of a dctionary field_name:value  
for r in shapefile.Reader(INPUT_FILE).shapeRecords():  
     atr = dict(zip(field_names, r.record))

# %%
print(field_names)
# Out:
# ['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3', 'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT', 'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG', 'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN', 'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT', 'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13', 'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS', 'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2', 'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID', 'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN', 'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB', 'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM', 'MIN_LABEL', 'MAX_LABEL', 'NE_ID', 'WIKIDATAID', 'NAME_AR', 'NAME_BN', 'NAME_DE', 'NAME_EN', 'NAME_ES', 'NAME_FR', 'NAME_EL', 'NAME_HI', 'NAME_HU', 'NAME_ID', 'NAME_IT', 'NAME_JA', 'NAME_KO', 'NAME_NL', 'NAME_PL', 'NAME_PT', 'NAME_RU', 'NAME_SV', 'NAME_TR', 'NAME_VI', 'NAME_ZH']

# %%
def main():
    countries = shapefile.Reader(INPUT_FILE).shapeRecords()
    results = {}

    for country in countries:
        t0 = time.process_time()
        name = country.record[8]
        # if name != 'Nauru': continue
        print('==== %s (%d -> %d) ====' % (
            name, len(country.shape.parts), len(country.shape.points)))
        points = list(map(lambda x: x, country.shape.points))

        parts_ = list(country.shape.parts) + [len(country.shape.points)]
        largest_part = (0, 1)
        for x1, x2 in zip(parts_, parts_[1:]):
            if x2 - x1 > largest_part[1] - largest_part[0]:
                largest_part = (x1, x2)
        print(parts_, largest_part)

        # Get the random points from the largest part.
        random_points = list(
            map(
                list,
                random.sample(points[largest_part[0]:largest_part[1]], 2)))

        # Get the middle points between them.
        lon, lat = list(
            pyproj.Geod(ellps='WGS84').npts(
                random_points[0][0], random_points[0][1],
                random_points[1][0], random_points[1][1],
                1)  # Just 1 point in-between them.
            )[0]

        to_proj = '+proj=aeqd +R=6371000 +lat_0=%.2f +lon_0=%.2f ' \
                  '+no_defs' % (lat, lon)
        print('Projection: %s' % to_proj)

        transform = lambda g: pyproj.transform(
            pyproj.Proj(FROM_PROJ),
            pyproj.Proj(to_proj),
            g[0], g[1])
        points = list(map(transform, points))

        parts = list(slice_at(points, country.shape.parts))
        max_xs, min_xs = maxmin(list(map(lambda t: t[0], points)))
        max_ys, min_ys = maxmin(list(map(lambda t: t[1], points)))

        center, radius, best_coeff = find_best_circle(
            parts, min_xs, min_ys, max_xs, max_ys)

        print('Time to compute roundness: %.3fs.' % (time.process_time() - t0))
        print('Result info: %f (%.4f, %.4f) %.4f' \
            % (best_coeff, center[0], center[1], radius))
        uri = 'data:image/png;base64,' + urllib.parse.quote(
            base64.b64encode(
                plot_country(name, parts, center, radius).getvalue()))
        print('Finished plotting %s.' % name)
        results[name] = (best_coeff, '<img src="%s" />' % uri)

    f = open('table', 'w')
    # Does python use theorems for free?
    # (https://www.mpi-sws.org/~dreyer/tor/papers/wadler.pdf)
    f.write(
        '\n'.join(
            map(lambda s: ' | '.join(map(str, s)),
                map(lambda r: [r[0]+1, r[1][0],
                               '%.3f' % r[1][1][0],
                               r[1][1][1]],
                    enumerate(
                        sorted(results.items(),
                               key=lambda z: (operator.itemgetter(1)(z))[0],
                               reverse=True))))))
    f.close()

# %%
main()
# Out:
# ==== Indonesia (264 -> 19565) ====
# [0, 17, 261, 2099, 4079, 4095, 4121, 4145, 4166, 4181, 4212, 4228, 4253, 4280, 4316, 4334, 4357, 4388, 4415, 4431, 4455, 4500, 4522, 4580, 5474, 5494, 5525, 5540, 5557, 5571, 5586, 5605, 5618, 5637, 5658, 5681, 5703, 5734, 5748, 5762, 5771, 5781, 5789, 5809, 5830, 5845, 5862, 5871, 5890, 5905, 5921, 5935, 5946, 5960, 5971, 5984, 7776, 7788, 7804, 9247, 9415, 9433, 9482, 9558, 9586, 9739, 9752, 10188, 10568, 10664, 10687, 10750, 10777, 10810, 10823, 10843, 10940, 10949, 11031, 11081, 11145, 11175, 11218, 11340, 11399, 11428, 11449, 11464, 11480, 11506, 11524, 11546, 11565, 11584, 11619, 11676, 11711, 11772, 11860, 11902, 11935, 11958, 11975, 12012, 12025, 12063, 12087, 12115, 12130, 12253, 12280, 12290, 12349, 12368, 12389, 12416, 12439, 12456, 12486, 12503, 12517, 12615, 12638, 12655, 12687, 12719, 12796, 12828, 12866, 13002, 13062, 13090, 13188, 13220, 13270, 13300, 13414, 13445, 13525, 13719, 13742, 13767, 13864, 13893, 13990, 14037, 14052, 14131, 14336, 14385, 14441, 14450, 14570, 14582, 14763, 14803, 14822, 14835, 14864, 14879, 14892, 14909, 14931, 14990, 15023, 15124, 15146, 15164, 15185, 15487, 15498, 15629, 15648, 15668, 15707, 15723, 15807, 15829, 15845, 15940, 16056, 16191, 16438, 16456, 16524, 16548, 16686, 16714, 16752, 16820, 16910, 17016, 17048, 17101, 17139, 17185, 17217, 17363, 17428, 17458, 17479, 17505, 17514, 17812, 17892, 17921, 17944, 17969, 18005, 18025, 18038, 18048, 18070, 18093, 18109, 18136, 18271, 18289, 18759, 18771, 18821, 18849, 18896, 18907, 18925, 18979, 18988, 19000, 19012, 19031, 19050, 19067, 19088, 19103, 19117, 19131, 19142, 19160, 19169, 19173, 19177, 19181, 19185, 19199, 19204, 19213, 19218, 19226, 19241, 19272, 19278, 19292, 19327, 19349, 19360, 19376, 19396, 19450, 19475, 19494, 19516, 19524, 19538, 19557, 19565] (2099, 4079)
# Projection: +proj=aeqd +R=6371000 +lat_0=-6.09 +lon_0=139.50 +no_defs
# Analyzing best overall circle...  Iterations: [15, 17]
# Analyzing best part circle... (1 out of 264) Iterations: [11, 17]
# Analyzing best part circle... (2 out of 264) Iterations: [25, 18]
# Analyzing best part circle... (3 out of 264) Iterations: [16, 17]
# Analyzing best part circle... (4 out of 264) Iterations: [23, 22]
# Analyzing best part circle... (5 out of 264) Iterations: [75, 22]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 486.339s.
# Result info: 0.397523 (-2664222.4362, 351720.8040) 789229.1593
# Finished plotting Indonesia.
# ==== Malaysia (17 -> 2549) ====
# [0, 27, 703, 2192, 2208, 2233, 2264, 2284, 2319, 2334, 2375, 2394, 2445, 2469, 2492, 2524, 2532, 2549] (703, 2192)
# Projection: +proj=aeqd +R=6371000 +lat_0=4.27 +lon_0=116.76 +no_defs
# Analyzing best overall circle...  Iterations: [15, 11]
# Analyzing best part circle... (1 out of 17) Iterations: [11, 7]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 15.339s.
# Result info: 0.391064 (-128399.0775, -26568.0092) 324547.9283
# Finished plotting Malaysia.
# ==== Chile (163 -> 17196) ====
# [0, 7290, 8276, 8289, 8323, 8360, 8366, 8372, 8380, 8404, 8431, 8500, 8513, 8583, 8617, 8637, 8664, 8688, 8720, 8737, 9314, 9419, 9611, 9708, 9738, 9833, 9873, 9910, 9937, 9997, 10036, 10268, 10433, 10526, 10561, 10633, 11067, 11094, 11150, 11461, 11469, 11548, 11584, 11640, 11704, 11733, 11744, 11771, 11827, 11887, 11913, 11979, 12016, 12119, 12170, 12202, 12310, 12341, 12425, 12447, 12484, 12514, 12622, 12677, 12723, 12735, 12869, 12969, 13000, 13201, 13288, 13320, 13365, 13443, 13539, 13575, 14140, 14167, 14189, 14245, 14326, 14346, 14362, 14386, 14486, 14527, 14605, 14772, 14831, 14888, 14931, 14947, 14971, 15006, 15046, 15062, 15152, 15182, 15217, 15236, 15263, 15288, 15340, 15382, 15423, 15441, 15456, 15476, 15502, 15523, 15583, 15621, 15637, 15669, 15695, 15715, 15743, 15767, 15801, 15818, 15858, 15875, 15900, 15930, 15948, 16085, 16106, 16127, 16141, 16162, 16178, 16190, 16223, 16235, 16262, 16271, 16304, 16329, 16378, 16405, 16427, 16446, 16480, 16503, 16517, 16884, 16901, 16916, 16932, 16944, 16959, 16974, 17004, 17019, 17033, 17067, 17086, 17102, 17119, 17129, 17147, 17158, 17174, 17196] (0, 7290)
# Projection: +proj=aeqd +R=6371000 +lat_0=-40.39 +lon_0=-71.87 +no_defs
# Analyzing best overall circle...  Iterations: [23, 17]
# Analyzing best part circle... (1 out of 163) Iterations: [14, 19]
# Fine-tuning the circle... Iterations: [7]
# Time to compute roundness: 126.288s.
# Result info: 0.292769 (209553.4849, 1837367.4075) 485608.0218
# Finished plotting Chile.
# ==== Bolivia (1 -> 1491) ====
# [0, 1491] (0, 1491)
# Projection: +proj=aeqd +R=6371000 +lat_0=-18.04 +lon_0=-65.86 +no_defs
# Analyzing best overall circle...  Iterations: [5, 9]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 4.287s.
# Result info: 0.848946 (117457.2195, 122262.0413) 589576.4808
# Finished plotting Bolivia.
# ==== Peru (5 -> 2421) ====
# [0, 2368, 2379, 2391, 2403, 2421] (0, 2368)
# Projection: +proj=aeqd +R=6371000 +lat_0=-13.21 +lon_0=-76.62 +no_defs
# Analyzing best overall circle...  Iterations: [17, 11]
# Analyzing best part circle... (1 out of 5) Iterations: [17, 11]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 22.290s.
# Result info: 0.679857 (257740.1215, 607152.7549) 642916.0277
# Finished plotting Peru.
# ==== Argentina (8 -> 4696) ====
# [0, 4270, 4281, 4472, 4620, 4645, 4659, 4681, 4696] (0, 4270)
# Projection: +proj=aeqd +R=6371000 +lat_0=-34.25 +lon_0=-61.13 +no_defs
# Analyzing best overall circle...  Iterations: [18, 13]
# Analyzing best part circle... (1 out of 8) Iterations: [17, 11]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 40.634s.
# Result info: 0.721221 (-296532.7025, 284929.4831) 943271.0693
# Finished plotting Argentina.
# ==== United Kingdom (138 -> 10125) ====
# [0, 97, 107, 575, 582, 629, 4336, 4346, 4364, 4399, 4454, 4491, 4500, 4511, 4534, 4558, 4591, 4609, 4618, 4676, 4689, 4699, 4708, 4781, 4797, 4815, 4843, 4864, 4911, 4937, 4982, 4997, 5013, 5037, 5130, 5203, 5222, 5270, 5304, 5402, 5426, 5468, 5477, 5491, 5503, 5514, 5525, 5547, 5713, 5742, 5781, 5800, 5811, 5820, 5908, 5945, 5980, 5994, 6098, 6396, 6403, 6411, 6426, 6443, 6804, 6832, 6877, 7005, 7046, 7072, 7107, 7165, 7219, 7237, 7264, 7681, 7757, 7825, 7852, 7870, 7879, 7885, 7893, 7902, 7909, 7915, 7921, 7927, 7936, 7948, 7965, 7977, 7999, 8016, 8029, 8043, 8055, 8074, 8081, 8515, 8549, 8577, 8650, 8668, 9061, 9078, 9123, 9649, 9687, 9694, 9703, 9707, 9721, 9733, 9741, 9751, 9761, 9770, 9801, 9813, 9835, 9856, 9881, 9941, 9962, 9987, 10003, 10024, 10037, 10046, 10057, 10064, 10070, 10078, 10092, 10098, 10106, 10118, 10125] (629, 4336)
# Projection: +proj=aeqd +R=6371000 +lat_0=53.65 +lon_0=-3.38 +no_defs
# Analyzing best overall circle...  Iterations: [23, 26]
# Analyzing best part circle... (1 out of 138) Iterations: [22, 18]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 126.018s.
# Result info: 0.575900 (56737.5425, -49075.1230) 298322.2430
# Finished plotting United Kingdom.
# ==== Cyprus (4 -> 301) ====
# [0, 20, 30, 253, 301] (30, 253)
# Projection: +proj=aeqd +R=6371000 +lat_0=35.17 +lon_0=32.65 +no_defs
# Analyzing best overall circle...  Iterations: [16, 13]
# Analyzing best part circle... (1 out of 4) Iterations: [17, 11]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 5.361s.
# Result info: 0.719758 (21618.9559, -27880.8456) 41458.4244
# Finished plotting Cyprus.
# ==== India (35 -> 7776) ====
# [0, 6800, 6813, 6825, 6835, 6847, 6854, 6862, 6871, 6879, 6888, 6893, 6898, 6964, 6991, 7027, 7040, 7081, 7100, 7121, 7136, 7153, 7196, 7224, 7237, 7260, 7281, 7306, 7679, 7688, 7701, 7720, 7738, 7751, 7761, 7776] (0, 6800)
# Projection: +proj=aeqd +R=6371000 +lat_0=21.89 +lon_0=80.41 +no_defs
# Analyzing best overall circle...  Iterations: [10, 18]
# Analyzing best part circle... (1 out of 35) Iterations: [16, 12]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 73.229s.
# Result info: 0.767130 (-182735.4191, 83452.5658) 1004550.4584
# Finished plotting India.
# ==== China (75 -> 14635) ====
# [0, 12171, 12842, 12876, 12902, 12944, 12967, 12988, 13017, 13052, 13091, 13115, 13156, 13186, 13215, 13229, 13257, 13272, 13286, 13297, 13343, 13352, 13368, 13428, 13477, 13507, 13575, 13593, 13637, 13676, 13702, 13768, 13813, 13823, 13829, 13839, 13850, 13860, 13871, 13880, 13893, 13901, 13921, 13932, 13940, 13948, 13957, 13979, 13998, 14007, 14022, 14038, 14085, 14130, 14150, 14213, 14280, 14294, 14313, 14324, 14342, 14376, 14402, 14413, 14431, 14447, 14474, 14492, 14512, 14529, 14542, 14569, 14596, 14612, 14631, 14635] (0, 12171)
# Projection: +proj=aeqd +R=6371000 +lat_0=24.27 +lon_0=115.30 +no_defs
# Analyzing best overall circle...  Iterations: [9, 18]
# Analyzing best part circle... (1 out of 75) Iterations: [13, 18]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 203.511s.
# Result info: 0.728903 (-1251028.4570, 1388718.3572) 1745982.6705
# Finished plotting China.
# ==== Israel (1 -> 370) ====
# [0, 370] (0, 370)
# Projection: +proj=aeqd +R=6371000 +lat_0=32.38 +lon_0=35.57 +no_defs
# Analyzing best overall circle...  Iterations: [13, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 3.363s.
# Result info: 0.586645 (-54027.4710, -110290.6402) 94779.4802
# Finished plotting Israel.
# ==== Lebanon (1 -> 311) ====
# [0, 311] (0, 311)
# Projection: +proj=aeqd +R=6371000 +lat_0=34.29 +lon_0=36.00 +no_defs
# Analyzing best overall circle...  Iterations: [7, 12]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 2.559s.
# Result info: 0.661613 (1348.7027, -24966.6629) 56413.4793
# Finished plotting Lebanon.
# ==== Ethiopia (1 -> 1074) ====
# [0, 1074] (0, 1074)
# Projection: +proj=aeqd +R=6371000 +lat_0=9.87 +lon_0=41.27 +no_defs
# Analyzing best overall circle...  Iterations: [14, 10]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 4.684s.
# Result info: 0.887853 (-191409.7878, -111682.7014) 600582.1612
# Finished plotting Ethiopia.
# ==== South Sudan (1 -> 1156) ====
# [0, 1156] (0, 1156)
# Projection: +proj=aeqd +R=6371000 +lat_0=6.22 +lon_0=26.55 +no_defs
# Analyzing best overall circle...  Iterations: [16, 15]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 6.679s.
# Result info: 0.804002 (467199.3162, 119507.2921) 448015.7397
# Finished plotting South Sudan.
# ==== Somalia (1 -> 668) ====
# [0, 668] (0, 668)
# Projection: +proj=aeqd +R=6371000 +lat_0=-1.03 +lon_0=41.11 +no_defs
# Analyzing best overall circle...  Iterations: [15, 14]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 3.871s.
# Result info: 0.548720 (350047.8587, 432435.6638) 389134.7441
# Finished plotting Somalia.
# ==== Kenya (2 -> 874) ====
# [0, 830, 874] (0, 830)
# Projection: +proj=aeqd +R=6371000 +lat_0=0.46 +lon_0=37.29 +no_defs
# Analyzing best overall circle...  Iterations: [13, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [13, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 11.120s.
# Result info: 0.852011 (64655.1868, -10663.1979) 432921.7204
# Finished plotting Kenya.
# ==== Pakistan (2 -> 2141) ====
# [0, 2125, 2141] (0, 2125)
# Projection: +proj=aeqd +R=6371000 +lat_0=30.93 +lon_0=68.99 +no_defs
# Analyzing best overall circle...  Iterations: [12, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 13]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 20.594s.
# Result info: 0.673347 (-86722.8521, -250027.0316) 527967.2350
# Finished plotting Pakistan.
# ==== Malawi (3 -> 815) ====
# [0, 786, 802, 815] (0, 786)
# Projection: +proj=aeqd +R=6371000 +lat_0=-14.59 +lon_0=35.09 +no_defs
# Analyzing best overall circle...  Iterations: [9, 13]
# Analyzing best part circle... (1 out of 3) Iterations: [9, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 8.017s.
# Result info: 0.538165 (-87872.2245, 196085.9993) 195397.5990
# Finished plotting Malawi.
# ==== United Republic of Tanzania (7 -> 1762) ====
# [0, 1389, 1452, 1558, 1720, 1732, 1746, 1762] (0, 1389)
# Projection: +proj=aeqd +R=6371000 +lat_0=-6.73 +lon_0=39.08 +no_defs
# Analyzing best overall circle...  Iterations: [10, 14]
# Analyzing best part circle... (1 out of 7) Iterations: [10, 14]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 18.615s.
# Result info: 0.857421 (-502233.2442, 40441.6977) 548909.2588
# Finished plotting United Republic of Tanzania.
# ==== Syria (1 -> 591) ====
# [0, 591] (0, 591)
# Projection: +proj=aeqd +R=6371000 +lat_0=33.43 +lon_0=36.28 +no_defs
# Analyzing best overall circle...  Iterations: [16, 15]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 5.439s.
# Result info: 0.820259 (206200.7356, 182294.3505) 243378.3549
# Finished plotting Syria.
# ==== Somaliland (1 -> 319) ====
# [0, 319] (0, 319)
# Projection: +proj=aeqd +R=6371000 +lat_0=9.56 +lon_0=45.34 +no_defs
# Analyzing best overall circle...  Iterations: [14, 9]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 2.486s.
# Result info: 0.749574 (163739.3888, 30047.3042) 231325.5593
# Finished plotting Somaliland.
# ==== France (146 -> 7363) ====
# [0, 487, 509, 3606, 3618, 3634, 3652, 3716, 3722, 3731, 3740, 3747, 3760, 3773, 3783, 3791, 3800, 3809, 3817, 3829, 3834, 3848, 3861, 3866, 3878, 3887, 3899, 3907, 3912, 3917, 3926, 3938, 3947, 3960, 3969, 3979, 3993, 4001, 4009, 4015, 4021, 4027, 4034, 4040, 4173, 4199, 4207, 4264, 4327, 4338, 4355, 4372, 4384, 4416, 4438, 4450, 4759, 4768, 4777, 4798, 4812, 4896, 4905, 4986, 4991, 5392, 5426, 5459, 5469, 5490, 5512, 5531, 5543, 5554, 5564, 5578, 5586, 5607, 5653, 5680, 5700, 5722, 5736, 5759, 5768, 5777, 5792, 5806, 5829, 5868, 5882, 5901, 5938, 5952, 5961, 5979, 6000, 6025, 6031, 6037, 6090, 6104, 6118, 6211, 6263, 6945, 6955, 6970, 6999, 7011, 7017, 7030, 7037, 7044, 7049, 7055, 7063, 7070, 7083, 7091, 7102, 7121, 7126, 7132, 7140, 7144, 7154, 7164, 7171, 7183, 7191, 7212, 7219, 7242, 7254, 7275, 7282, 7288, 7300, 7307, 7315, 7328, 7346, 7350, 7354, 7358, 7363] (509, 3606)
# Projection: +proj=aeqd +R=6371000 +lat_0=45.54 +lon_0=2.56 +no_defs
# Analyzing best overall circle...  Iterations: [22, 25]
# Analyzing best part circle... (1 out of 146) Iterations: [12, 11]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 72.742s.
# Result info: 0.671168 (-19765.6873, 114412.5851) 502464.7443
# Finished plotting France.
# ==== Suriname (1 -> 737) ====
# [0, 737] (0, 737)
# Projection: +proj=aeqd +R=6371000 +lat_0=2.59 +lon_0=-55.87 +no_defs
# Analyzing best overall circle...  Iterations: [14, 16]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 6.040s.
# Result info: 0.897211 (-7980.3225, 169073.2943) 215445.8915
# Finished plotting Suriname.
# ==== Guyana (2 -> 1121) ====
# [0, 1107, 1121] (0, 1107)
# Projection: +proj=aeqd +R=6371000 +lat_0=3.35 +lon_0=-57.47 +no_defs
# Analyzing best overall circle...  Iterations: [13, 17]
# Analyzing best part circle... (1 out of 2) Iterations: [13, 17]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 14.186s.
# Result info: 0.684608 (-195215.0106, 178812.6281) 259882.6179
# Finished plotting Guyana.
# ==== South Korea (53 -> 3060) ====
# [0, 1593, 1637, 1655, 1716, 1736, 1789, 1815, 1836, 1864, 1887, 1945, 2024, 2051, 2102, 2117, 2139, 2184, 2202, 2227, 2253, 2276, 2308, 2320, 2342, 2372, 2389, 2418, 2446, 2457, 2483, 2500, 2525, 2545, 2562, 2586, 2596, 2616, 2630, 2656, 2682, 2703, 2733, 2753, 2791, 2830, 2869, 2899, 2925, 2961, 2977, 3015, 3055, 3060] (0, 1593)
# Projection: +proj=aeqd +R=6371000 +lat_0=35.69 +lon_0=126.75 +no_defs
# Analyzing best overall circle...  Iterations: [9, 16]
# Analyzing best part circle... (1 out of 53) Iterations: [10, 9]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 47.006s.
# Result info: 0.818638 (95394.0332, 90443.0917) 177185.6246
# Finished plotting South Korea.
# ==== North Korea (10 -> 1782) ====
# [0, 1613, 1639, 1654, 1674, 1688, 1709, 1721, 1739, 1751, 1782] (0, 1613)
# Projection: +proj=aeqd +R=6371000 +lat_0=40.03 +lon_0=128.43 +no_defs
# Analyzing best overall circle...  Iterations: [9, 15]
# Analyzing best part circle... (1 out of 10) Iterations: [11, 15]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 28.308s.
# Result info: 0.724528 (-135833.0926, -23540.3678) 197352.5587
# Finished plotting North Korea.
# ==== Morocco (1 -> 1019) ====
# [0, 1019] (0, 1019)
# Projection: +proj=aeqd +R=6371000 +lat_0=34.03 +lon_0=-7.37 +no_defs
# Analyzing best overall circle...  Iterations: [15, 11]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 5.193s.
# Result info: 0.596103 (158287.5204, -213158.6367) 434502.0065
# Finished plotting Morocco.
# ==== Western Sahara (1 -> 288) ====
# [0, 288] (0, 288)
# Projection: +proj=aeqd +R=6371000 +lat_0=24.86 +lon_0=-12.84 +no_defs
# Analyzing best overall circle...  Iterations: [17, 25]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 3.874s.
# Result info: 0.475311 (-48583.1203, -224610.2192) 169900.5285
# Finished plotting Western Sahara.
# ==== Costa Rica (4 -> 815) ====
# [0, 777, 798, 808, 815] (0, 777)
# Projection: +proj=aeqd +R=6371000 +lat_0=8.26 +lon_0=-83.25 +no_defs
# Analyzing best overall circle...  Iterations: [25, 11]
# Analyzing best part circle... (1 out of 4) Iterations: [14, 13]
# Fine-tuning the circle... Iterations: [8]
# Time to compute roundness: 16.955s.
# Result info: 0.666835 (-136845.3270, 209122.2861) 127850.8233
# Finished plotting Costa Rica.
# ==== Nicaragua (4 -> 927) ====
# [0, 886, 902, 909, 927] (0, 886)
# Projection: +proj=aeqd +R=6371000 +lat_0=14.23 +lon_0=-85.58 +no_defs
# Analyzing best overall circle...  Iterations: [20, 13]
# Analyzing best part circle... (1 out of 4) Iterations: [17, 8]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 15.388s.
# Result info: 0.865549 (58878.3689, -152945.3461) 202756.6225
# Finished plotting Nicaragua.
# ==== Republic of the Congo (1 -> 1345) ====
# [0, 1345] (0, 1345)
# Projection: +proj=aeqd +R=6371000 +lat_0=-1.45 +lon_0=14.81 +no_defs
# Analyzing best overall circle...  Iterations: [6, 18]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 6.422s.
# Result info: 0.624929 (9651.2230, 54723.7959) 332330.9994
# Finished plotting Republic of the Congo.
# ==== Democratic Republic of the Congo (2 -> 2868) ====
# [0, 2849, 2868] (0, 2849)
# Projection: +proj=aeqd +R=6371000 +lat_0=-6.28 +lon_0=17.72 +no_defs
# Analyzing best overall circle...  Iterations: [8, 15]
# Analyzing best part circle... (1 out of 2) Iterations: [8, 15]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 22.079s.
# Result info: 0.857944 (680259.9005, 373704.4432) 864401.7933
# Finished plotting Democratic Republic of the Congo.
# ==== Bhutan (1 -> 328) ====
# [0, 328] (0, 328)
# Projection: +proj=aeqd +R=6371000 +lat_0=27.35 +lon_0=88.92 +no_defs
# Analyzing best overall circle...  Iterations: [8, 14]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 2.619s.
# Result info: 0.792971 (146133.5671, 10371.9099) 113431.5124
# Finished plotting Bhutan.
# ==== Ukraine (4 -> 2659) ====
# [0, 2608, 2624, 2640, 2659] (0, 2608)
# Projection: +proj=aeqd +R=6371000 +lat_0=47.88 +lon_0=32.43 +no_defs
# Analyzing best overall circle...  Iterations: [10, 19]
# Analyzing best part circle... (1 out of 4) Iterations: [10, 19]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 32.710s.
# Result info: 0.733866 (-85659.1450, 119580.4521) 426068.9872
# Finished plotting Ukraine.
# ==== Belarus (1 -> 1173) ====
# [0, 1173] (0, 1173)
# Projection: +proj=aeqd +R=6371000 +lat_0=54.31 +lon_0=25.62 +no_defs
# Analyzing best overall circle...  Iterations: [16, 16]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 9.767s.
# Result info: 0.876452 (172125.2549, -74546.2256) 256535.6912
# Finished plotting Belarus.
# ==== Namibia (1 -> 1183) ====
# [0, 1183] (0, 1183)
# Projection: +proj=aeqd +R=6371000 +lat_0=-17.90 +lon_0=22.93 +no_defs
# Analyzing best overall circle...  Iterations: [9, 21]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 6.106s.
# Result info: 0.761270 (-620728.3257, -448062.0974) 513150.5197
# Finished plotting Namibia.
# ==== South Africa (4 -> 2207) ====
# [0, 1848, 2172, 2198, 2207] (0, 1848)
# Projection: +proj=aeqd +R=6371000 +lat_0=-28.44 +lon_0=26.04 +no_defs
# Analyzing best overall circle...  Iterations: [10, 15]
# Analyzing best part circle... (1 out of 4) Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 16.617s.
# Result info: 0.799562 (-113437.7090, -43527.3284) 638880.1477
# Finished plotting South Africa.
# ==== Netherlands (15 -> 933) ====
# [0, 9, 602, 666, 710, 736, 781, 791, 828, 854, 867, 889, 901, 915, 925, 933] (9, 602)
# Projection: +proj=aeqd +R=6371000 +lat_0=52.68 +lon_0=5.87 +no_defs
# Analyzing best overall circle...  Iterations: [1, 25]
# Analyzing best part circle... (1 out of 15) Iterations: [16, 14]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 13.137s.
# Result info: 0.759593 (-19222.8427, -46248.7529) 110335.0589
# Finished plotting Netherlands.
# ==== Oman (7 -> 1033) ====
# [0, 20, 27, 234, 933, 947, 963, 1033] (234, 933)
# Projection: +proj=aeqd +R=6371000 +lat_0=20.48 +lon_0=58.73 +no_defs
# Analyzing best overall circle...  Iterations: [11, 18]
# Analyzing best part circle... (1 out of 7) Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 10.041s.
# Result info: 0.671032 (-209914.8784, 92263.1515) 315293.8080
# Finished plotting Oman.
# ==== Uzbekistan (4 -> 1666) ====
# [0, 14, 1605, 1618, 1666] (14, 1605)
# Projection: +proj=aeqd +R=6371000 +lat_0=40.67 +lon_0=70.72 +no_defs
# Analyzing best overall circle...  Iterations: [11, 20]
# Analyzing best part circle... (1 out of 4) Iterations: [11, 20]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 15.548s.
# Result info: 0.579818 (-506208.1359, 62203.4529) 377528.5329
# Finished plotting Uzbekistan.
# ==== Baykonur Cosmodrome (6 -> 4146) ====
# [0, 4020, 4044, 4081, 4113, 4133, 4146] (0, 4020)
# Projection: +proj=aeqd +R=6371000 +lat_0=49.83 +lon_0=65.50 +no_defs
# Analyzing best overall circle...  Iterations: [13, 16]
# Analyzing best part circle... (1 out of 6) Iterations: [13, 16]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 34.999s.
# Result info: 0.754429 (384304.2120, -162181.3864) 929970.8834
# Finished plotting Baykonur Cosmodrome.
# ==== Tajikistan (3 -> 1257) ====
# [0, 13, 1238, 1257] (13, 1238)
# Projection: +proj=aeqd +R=6371000 +lat_0=39.94 +lon_0=69.70 +no_defs
# Analyzing best overall circle...  Iterations: [14, 13]
# Analyzing best part circle... (1 out of 3) Iterations: [14, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 13.609s.
# Result info: 0.648353 (78613.6928, -143661.0279) 212836.9332
# Finished plotting Tajikistan.
# ==== Lithuania (2 -> 562) ====
# [0, 530, 562] (0, 530)
# Projection: +proj=aeqd +R=6371000 +lat_0=55.21 +lon_0=24.51 +no_defs
# Analyzing best overall circle...  Iterations: [13, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [6, 15]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 6.970s.
# Result info: 0.855585 (-34085.5538, 6511.2425) 143396.2574
# Finished plotting Lithuania.
# ==== Brazil (43 -> 11116) ====
# [0, 9149, 9195, 9234, 9277, 9308, 9345, 9372, 9418, 9447, 9471, 9493, 9534, 9561, 9669, 9706, 10262, 10306, 10347, 10386, 10397, 10460, 10519, 10557, 10581, 10606, 10638, 10661, 10670, 10679, 10742, 10780, 10808, 10834, 10882, 10959, 10975, 10988, 11006, 11030, 11048, 11079, 11095, 11116] (0, 9149)
# Projection: +proj=aeqd +R=6371000 +lat_0=-11.64 +lon_0=-64.12 +no_defs
# Analyzing best overall circle...  Iterations: [13, 13]
# Analyzing best part circle... (1 out of 43) Iterations: [11, 17]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 134.506s.
# Result info: 0.803431 (1268649.7096, 64156.4411) 1656595.7859
# Finished plotting Brazil.
# ==== Uruguay (1 -> 581) ====
# [0, 581] (0, 581)
# Projection: +proj=aeqd +R=6371000 +lat_0=-32.61 +lon_0=-56.21 +no_defs
# Analyzing best overall circle...  Iterations: [19, 14]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 4.699s.
# Result info: 0.894712 (21469.3745, -37632.4739) 237658.4617
# Finished plotting Uruguay.
# ==== Mongolia (1 -> 1494) ====
# [0, 1494] (0, 1494)
# Projection: +proj=aeqd +R=6371000 +lat_0=46.53 +lon_0=101.27 +no_defs
# Analyzing best overall circle...  Iterations: [5, 12]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 4.739s.
# Result info: 0.744189 (154487.2995, 35955.4693) 705505.5645
# Finished plotting Mongolia.
# ==== Russia (214 -> 36756) ====
# [0, 22908, 23112, 23536, 24847, 24905, 24987, 25016, 26048, 26061, 26078, 26168, 26186, 26197, 26213, 26289, 26326, 26354, 27319, 27332, 27350, 27362, 27376, 27412, 27429, 27470, 27477, 27500, 28642, 28659, 28668, 28685, 28703, 28716, 28738, 28757, 28776, 28823, 28955, 29135, 29218, 29265, 29277, 29296, 29311, 29339, 29355, 29373, 29387, 29500, 29535, 29548, 29555, 29579, 29611, 29658, 29713, 29806, 29896, 29918, 30010, 30019, 30034, 30047, 30067, 30098, 30119, 30134, 30182, 30194, 30210, 30222, 30247, 30258, 30371, 30423, 30605, 30631, 30650, 30676, 30698, 30811, 30848, 30882, 30907, 30922, 30982, 31020, 31039, 31056, 31156, 31170, 31209, 31283, 31314, 31338, 31363, 31380, 31421, 31468, 31488, 31505, 31561, 31576, 31609, 31637, 31663, 31715, 31726, 31820, 31988, 32004, 32015, 32082, 32097, 32124, 32631, 32710, 32724, 32786, 32817, 32837, 32863, 32888, 32932, 32942, 32957, 32967, 33003, 33030, 33066, 33100, 33463, 33498, 33560, 33596, 33605, 34032, 34061, 34097, 34219, 34315, 34342, 34379, 34647, 34669, 34686, 34733, 34798, 34835, 34861, 35141, 35188, 35215, 35250, 35263, 35329, 35349, 35385, 35436, 35490, 35574, 35610, 35637, 35703, 35721, 35797, 35820, 35833, 35873, 35879, 35901, 35920, 35951, 35975, 35990, 35998, 36008, 36020, 36030, 36041, 36051, 36076, 36095, 36126, 36164, 36196, 36214, 36233, 36247, 36260, 36283, 36295, 36332, 36375, 36400, 36429, 36445, 36458, 36472, 36492, 36516, 36537, 36566, 36577, 36586, 36601, 36620, 36640, 36658, 36677, 36692, 36719, 36743, 36756] (0, 22908)
# Projection: +proj=aeqd +R=6371000 +lat_0=54.90 +lon_0=82.15 +no_defs
# Analyzing best overall circle...  Iterations: [14, 16]
# Analyzing best part circle... (1 out of 214) Iterations: [11, 16]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 468.433s.
# Result info: 0.659082 (1161429.0244, 1512345.8033) 2351586.3360
# Finished plotting Russia.
# ==== Czechia (1 -> 922) ====
# [0, 922] (0, 922)
# Projection: +proj=aeqd +R=6371000 +lat_0=50.77 +lon_0=15.75 +no_defs
# Analyzing best overall circle...  Iterations: [16, 16]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 6.248s.
# Result info: 0.782729 (-37688.6135, -114414.2618) 158140.6372
# Finished plotting Czechia.
# ==== Germany (22 -> 3027) ====
# [0, 2374, 2462, 2484, 2489, 2499, 2509, 2523, 2539, 2553, 2566, 2584, 2594, 2614, 2642, 2670, 2922, 2939, 2958, 2999, 3012, 3022, 3027] (0, 2374)
# Projection: +proj=aeqd +R=6371000 +lat_0=54.43 +lon_0=8.84 +no_defs
# Analyzing best overall circle...  Iterations: [11, 14]
# Analyzing best part circle... (1 out of 22) Iterations: [11, 13]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 31.661s.
# Result info: 0.852807 (123695.8707, -390610.2429) 337078.0569
# Finished plotting Germany.
# ==== Estonia (8 -> 1044) ====
# [0, 605, 614, 849, 885, 915, 1023, 1032, 1044] (0, 605)
# Projection: +proj=aeqd +R=6371000 +lat_0=59.19 +lon_0=24.80 +no_defs
# Analyzing best overall circle...  Iterations: [9, 14]
# Analyzing best part circle... (1 out of 8) Iterations: [6, 11]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 10.382s.
# Result info: 0.813488 (54620.9029, -62187.6567) 120415.0441
# Finished plotting Estonia.
# ==== Latvia (1 -> 543) ====
# [0, 543] (0, 543)
# Projection: +proj=aeqd +R=6371000 +lat_0=56.79 +lon_0=25.17 +no_defs
# Analyzing best overall circle...  Iterations: [10, 17]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 3.853s.
# Result info: 0.705255 (29897.8895, -1099.5257) 143051.5106
# Finished plotting Latvia.
# ==== Norway (120 -> 15817) ====
# [0, 7911, 7921, 7939, 8047, 8159, 8199, 8291, 8338, 8388, 8437, 8470, 8509, 8561, 8591, 8638, 8669, 8683, 8708, 8734, 8758, 8812, 8828, 8859, 8893, 8963, 9004, 9034, 9072, 9098, 9138, 9219, 9252, 9286, 9342, 9376, 9458, 9500, 9639, 9673, 9693, 9721, 10082, 10101, 10313, 10378, 10652, 10781, 10794, 10803, 10821, 10829, 10918, 10982, 11036, 11089, 11204, 11257, 11527, 11576, 11682, 11717, 11763, 11806, 11834, 11853, 11870, 11895, 11928, 11949, 11988, 12000, 12015, 12066, 12089, 12164, 12199, 12234, 12405, 12511, 12540, 12642, 12673, 12686, 12719, 12740, 12763, 12773, 14272, 14294, 14320, 14334, 14347, 15050, 15064, 15077, 15094, 15128, 15146, 15175, 15200, 15258, 15307, 15347, 15383, 15412, 15427, 15446, 15472, 15498, 15524, 15557, 15602, 15630, 15670, 15689, 15715, 15727, 15764, 15791, 15817] (0, 7911)
# Projection: +proj=aeqd +R=6371000 +lat_0=64.97 +lon_0=12.99 +no_defs
# Analyzing best overall circle...  Iterations: [1, 21]
# Analyzing best part circle... (1 out of 120) Iterations: [14, 16]
# Fine-tuning the circle... Iterations: [8]
# Time to compute roundness: 152.448s.
# Result info: 0.499917 (-215618.7903, -418078.3640) 348092.0061
# Finished plotting Norway.
# ==== Sweden (41 -> 4665) ====
# [0, 3388, 3518, 3723, 3765, 3811, 3859, 3868, 3887, 3927, 3937, 3979, 3990, 4013, 4040, 4058, 4066, 4079, 4090, 4152, 4173, 4194, 4222, 4252, 4273, 4284, 4324, 4353, 4394, 4433, 4459, 4468, 4493, 4510, 4531, 4543, 4572, 4593, 4601, 4622, 4651, 4665] (0, 3388)
# Projection: +proj=aeqd +R=6371000 +lat_0=56.42 +lon_0=14.29 +no_defs
# Analyzing best overall circle...  Iterations: [10, 16]
# Analyzing best part circle... (1 out of 41) Iterations: [10, 16]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 59.862s.
# Result info: 0.514430 (96620.3379, 636446.3029) 376273.3773
# Finished plotting Sweden.
# ==== Finland (58 -> 3697) ====
# [0, 2199, 2224, 2245, 2273, 2305, 2324, 2339, 2348, 2357, 2397, 2417, 2430, 2446, 2532, 2563, 2587, 2787, 2840, 2852, 2866, 2893, 2917, 2948, 3007, 3023, 3066, 3078, 3095, 3112, 3144, 3153, 3175, 3190, 3214, 3228, 3242, 3263, 3273, 3282, 3297, 3316, 3327, 3335, 3353, 3372, 3401, 3456, 3492, 3528, 3543, 3558, 3582, 3600, 3611, 3632, 3654, 3668, 3697] (0, 2199)
# Projection: +proj=aeqd +R=6371000 +lat_0=61.34 +lon_0=22.13 +no_defs
# Analyzing best overall circle...  Iterations: [14, 9]
# Analyzing best part circle... (1 out of 58) Iterations: [13, 8]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 40.714s.
# Result info: 0.680017 (158196.8851, 215567.9671) 325259.6757
# Finished plotting Finland.
# ==== Vietnam (25 -> 4166) ====
# [0, 3511, 3544, 3561, 3587, 3613, 3652, 3680, 3713, 3726, 3765, 3818, 3901, 3925, 3946, 3963, 3990, 4010, 4061, 4073, 4095, 4104, 4120, 4134, 4157, 4166] (0, 3511)
# Projection: +proj=aeqd +R=6371000 +lat_0=16.37 +lon_0=107.74 +no_defs
# Analyzing best overall circle...  Iterations: [16, 24]
# Analyzing best part circle... (1 out of 25) Iterations: [16, 24]
# Fine-tuning the circle... Iterations: [15]
# Time to compute roundness: 70.565s.
# Result info: 0.450850 (-290683.0240, 453544.5908) 324189.3058
# Finished plotting Vietnam.
# ==== Cambodia (6 -> 1209) ====
# [0, 1090, 1106, 1136, 1165, 1186, 1209] (0, 1090)
# Projection: +proj=aeqd +R=6371000 +lat_0=13.67 +lon_0=103.58 +no_defs
# Analyzing best overall circle...  Iterations: [12, 15]
# Analyzing best part circle... (1 out of 6) Iterations: [12, 15]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 16.754s.
# Result info: 0.855133 (135348.1535, -109072.1836) 240610.1098
# Finished plotting Cambodia.
# ==== Luxembourg (1 -> 197) ====
# [0, 197] (0, 197)
# Projection: +proj=aeqd +R=6371000 +lat_0=49.78 +lon_0=5.79 +no_defs
# Analyzing best overall circle...  Iterations: [9, 11]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 2.087s.
# Result info: 0.808162 (19658.1636, -6062.3181) 28754.7114
# Finished plotting Luxembourg.
# ==== United Arab Emirates (11 -> 798) ====
# [0, 580, 600, 607, 659, 675, 690, 734, 749, 768, 785, 798] (0, 580)
# Projection: +proj=aeqd +R=6371000 +lat_0=24.48 +lon_0=54.00 +no_defs
# Analyzing best overall circle...  Iterations: [11, 10]
# Analyzing best part circle... (1 out of 11) Iterations: [11, 10]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 12.138s.
# Result info: 0.672705 (5463.9861, -77239.4147) 150820.1545
# Finished plotting United Arab Emirates.
# ==== Belgium (1 -> 648) ====
# [0, 648] (0, 648)
# Projection: +proj=aeqd +R=6371000 +lat_0=49.78 +lon_0=5.07 +no_defs
# Analyzing best overall circle...  Iterations: [8, 12]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 3.958s.
# Result info: 0.802684 (-20977.5132, 87433.6001) 98638.2262
# Finished plotting Belgium.
# ==== Georgia (1 -> 533) ====
# [0, 533] (0, 533)
# Projection: +proj=aeqd +R=6371000 +lat_0=41.33 +lon_0=44.82 +no_defs
# Analyzing best overall circle...  Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 3.193s.
# Result info: 0.702404 (-109313.7817, 97998.9954) 148670.3114
# Finished plotting Georgia.
# ==== Macedonia (1 -> 363) ====
# [0, 363] (0, 363)
# Projection: +proj=aeqd +R=6371000 +lat_0=41.17 +lon_0=22.19 +no_defs
# Analyzing best overall circle...  Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 2.884s.
# Result info: 0.866502 (-39083.8033, 47325.1123) 89867.5536
# Finished plotting Macedonia.
# ==== Albania (1 -> 554) ====
# [0, 554] (0, 554)
# Projection: +proj=aeqd +R=6371000 +lat_0=41.13 +lon_0=20.67 +no_defs
# Analyzing best overall circle...  Iterations: [11, 15]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 3.781s.
# Result info: 0.678782 (-45914.7453, -26864.9502) 94864.4376
# Finished plotting Albania.
# ==== Azerbaijan (7 -> 957) ====
# [0, 9, 754, 767, 920, 929, 942, 957] (9, 754)
# Projection: +proj=aeqd +R=6371000 +lat_0=40.94 +lon_0=47.96 +no_defs
# Analyzing best overall circle...  Iterations: [12, 13]
# Analyzing best part circle... (1 out of 7) Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 11.805s.
# Result info: 0.791971 (-23879.8079, -72037.6820) 165669.9376
# Finished plotting Azerbaijan.
# ==== Kosovo (1 -> 271) ====
# [0, 271] (0, 271)
# Projection: +proj=aeqd +R=6371000 +lat_0=42.86 +lon_0=21.38 +no_defs
# Analyzing best overall circle...  Iterations: [10, 14]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 3.022s.
# Result info: 0.880846 (-40957.4907, -31375.4469) 58915.5764
# Finished plotting Kosovo.
# ==== Turkey (6 -> 3640) ====
# [0, 3050, 3545, 3562, 3596, 3622, 3640] (0, 3050)
# Projection: +proj=aeqd +R=6371000 +lat_0=36.46 +lon_0=32.67 +no_defs
# Analyzing best overall circle...  Iterations: [12, 15]
# Analyzing best part circle... (1 out of 6) Iterations: [14, 14]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 34.945s.
# Result info: 0.660583 (124137.0932, 258043.9401) 498604.2031
# Finished plotting Turkey.
# ==== Spain (23 -> 2978) ====
# [0, 14, 22, 2180, 2192, 2232, 2307, 2326, 2411, 2481, 2523, 2587, 2597, 2612, 2645, 2714, 2868, 2935, 2943, 2952, 2958, 2966, 2972, 2978] (22, 2180)
# Projection: +proj=aeqd +R=6371000 +lat_0=38.86 +lon_0=-0.15 +no_defs
# Analyzing best overall circle...  Iterations: [12, 15]
# Analyzing best part circle... (1 out of 23) Iterations: [11, 14]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 26.856s.
# Result info: 0.830871 (-329538.4611, 158112.0703) 401792.2170
# Finished plotting Spain.
# ==== Laos (1 -> 1761) ====
# [0, 1761] (0, 1761)
# Projection: +proj=aeqd +R=6371000 +lat_0=19.33 +lon_0=103.35 +no_defs
# Analyzing best overall circle...  Iterations: [14, 16]
# Fine-tuning the circle... Iterations: [7]
# Time to compute roundness: 9.384s.
# Result info: 0.621762 (-76846.6950, 35839.9856) 269892.7654
# Finished plotting Laos.
# ==== Kyrgyzstan (4 -> 1206) ====
# [0, 1125, 1139, 1187, 1206] (0, 1125)
# Projection: +proj=aeqd +R=6371000 +lat_0=41.07 +lon_0=75.74 +no_defs
# Analyzing best overall circle...  Iterations: [9, 14]
# Analyzing best part circle... (1 out of 4) Iterations: [9, 14]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 11.209s.
# Result info: 0.689721 (-163491.2527, 35176.7344) 252234.9290
# Finished plotting Kyrgyzstan.
# ==== Armenia (4 -> 434) ====
# [0, 403, 412, 421, 434] (0, 403)
# Projection: +proj=aeqd +R=6371000 +lat_0=40.25 +lon_0=45.79 +no_defs
# Analyzing best overall circle...  Iterations: [10, 10]
# Analyzing best part circle... (1 out of 4) Iterations: [10, 10]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 6.785s.
# Result info: 0.768016 (-87177.2566, 17141.5564) 97085.0727
# Finished plotting Armenia.
# ==== Denmark (154 -> 22798) ====
# [0, 970, 16518, 16527, 16581, 16606, 16618, 16647, 16660, 16685, 16701, 16716, 16737, 16748, 16771, 16783, 16795, 16804, 16814, 16822, 16831, 16842, 16854, 16895, 16909, 16932, 16947, 16965, 16979, 16992, 17014, 17036, 17047, 17104, 17142, 17211, 17242, 17292, 17360, 17397, 17444, 17462, 17684, 17706, 17744, 18219, 18236, 18319, 18352, 18420, 18452, 18487, 18514, 18611, 18689, 18701, 18710, 18784, 18810, 18843, 18905, 18983, 19079, 19131, 19155, 19221, 19239, 19269, 19282, 19299, 19356, 19373, 19385, 19427, 19525, 19560, 19580, 19600, 19634, 19661, 19781, 19807, 19837, 19852, 19878, 19890, 19909, 19932, 19970, 19976, 20022, 20070, 20147, 20354, 20370, 20383, 20405, 20432, 20462, 20488, 20506, 20560, 20616, 20698, 20731, 20803, 20832, 20852, 20868, 20905, 20926, 20962, 21016, 21032, 21061, 21089, 21122, 21136, 21173, 21203, 21318, 21356, 21524, 21553, 21666, 21678, 21748, 21810, 21845, 21872, 21927, 22069, 22157, 22182, 22213, 22240, 22273, 22290, 22313, 22354, 22373, 22392, 22443, 22488, 22531, 22562, 22582, 22606, 22616, 22634, 22649, 22669, 22696, 22781, 22798] (970, 16518)
# Projection: +proj=aeqd +R=6371000 +lat_0=72.76 +lon_0=-53.58 +no_defs
# Analyzing best overall circle...  Iterations: [15, 18]
# Analyzing best part circle... (1 out of 154) Iterations: [24, 14]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 344.282s.
# Result info: 0.752245 (337983.7490, 232478.5889) 834693.9012
# Finished plotting Denmark.
# ==== Libya (1 -> 660) ====
# [0, 660] (0, 660)
# Projection: +proj=aeqd +R=6371000 +lat_0=22.46 +lon_0=17.75 +no_defs
# Analyzing best overall circle...  Iterations: [13, 13]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 3.754s.
# Result info: 0.826914 (3980.9365, 563771.1397) 720534.4014
# Finished plotting Libya.
# ==== Tunisia (4 -> 700) ====
# [0, 616, 657, 668, 700] (0, 616)
# Projection: +proj=aeqd +R=6371000 +lat_0=34.58 +lon_0=10.84 +no_defs
# Analyzing best overall circle...  Iterations: [10, 17]
# Analyzing best part circle... (1 out of 4) Iterations: [10, 17]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 10.595s.
# Result info: 0.705308 (-90552.1019, -70936.9777) 223269.1820
# Finished plotting Tunisia.
# ==== Romania (1 -> 1198) ====
# [0, 1198] (0, 1198)
# Projection: +proj=aeqd +R=6371000 +lat_0=44.51 +lon_0=26.81 +no_defs
# Analyzing best overall circle...  Iterations: [13, 13]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 6.674s.
# Result info: 0.894187 (-155032.2476, 161172.1698) 273873.5044
# Finished plotting Romania.
# ==== Hungary (1 -> 848) ====
# [0, 848] (0, 848)
# Projection: +proj=aeqd +R=6371000 +lat_0=45.90 +lon_0=17.51 +no_defs
# Analyzing best overall circle...  Iterations: [16, 12]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 4.808s.
# Result info: 0.765981 (118548.3104, 133936.3992) 172018.4888
# Finished plotting Hungary.
# ==== Slovakia (1 -> 572) ====
# [0, 572] (0, 572)
# Projection: +proj=aeqd +R=6371000 +lat_0=48.35 +lon_0=20.38 +no_defs
# Analyzing best overall circle...  Iterations: [15, 13]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 4.330s.
# Result info: 0.685022 (-119736.5746, 30249.9351) 123969.4916
# Finished plotting Slovakia.
# ==== Poland (1 -> 1332) ====
# [0, 1332] (0, 1332)
# Projection: +proj=aeqd +R=6371000 +lat_0=50.31 +lon_0=16.38 +no_defs
# Analyzing best overall circle...  Iterations: [9, 12]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 6.602s.
# Result info: 0.902434 (202161.1249, 210769.9221) 315233.1889
# Finished plotting Poland.
# ==== Ireland (7 -> 2394) ====
# [0, 2261, 2274, 2323, 2345, 2359, 2376, 2394] (0, 2261)
# Projection: +proj=aeqd +R=6371000 +lat_0=51.69 +lon_0=-9.79 +no_defs
# Analyzing best overall circle...  Iterations: [6, 21]
# Analyzing best part circle... (1 out of 7) Iterations: [6, 21]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 33.097s.
# Result info: 0.822255 (105888.2605, 160529.2074) 148322.1497
# Finished plotting Ireland.
# ==== Greece (74 -> 6096) ====
# [0, 2714, 2732, 2765, 3155, 3242, 3257, 3295, 3316, 3405, 3434, 3470, 3518, 3570, 3583, 3595, 3608, 3651, 3663, 3690, 3706, 3729, 3741, 3780, 3791, 3840, 3854, 3883, 3942, 3959, 4004, 4054, 4104, 4120, 4137, 4170, 4205, 4243, 4261, 4303, 4332, 4365, 4390, 4461, 4508, 4577, 4631, 4737, 4784, 4792, 4892, 4926, 4989, 5052, 5340, 5363, 5393, 5405, 5424, 5579, 5591, 5689, 5824, 5842, 5893, 5900, 5912, 5929, 5941, 5985, 6021, 6034, 6051, 6076, 6096] (0, 2714)
# Projection: +proj=aeqd +R=6371000 +lat_0=39.85 +lon_0=23.66 +no_defs
# Analyzing best overall circle...  Iterations: [22, 18]
# Analyzing best part circle... (1 out of 74) Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 86.765s.
# Result info: 0.633879 (-105560.8208, -63120.8964) 204508.0088
# Finished plotting Greece.
# ==== Zambia (1 -> 1508) ====
# [0, 1508] (0, 1508)
# Projection: +proj=aeqd +R=6371000 +lat_0=-16.32 +lon_0=25.75 +no_defs
# Analyzing best overall circle...  Iterations: [7, 13]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 5.349s.
# Result info: 0.698574 (290155.1755, 394545.0722) 490413.6387
# Finished plotting Zambia.
# ==== Sierra Leone (2 -> 695) ====
# [0, 651, 695] (0, 651)
# Projection: +proj=aeqd +R=6371000 +lat_0=8.64 +lon_0=-13.13 +no_defs
# Analyzing best overall circle...  Iterations: [8, 12]
# Analyzing best part circle... (1 out of 2) Iterations: [8, 12]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 8.974s.
# Result info: 0.933685 (146310.5963, -8490.2638) 151386.5086
# Finished plotting Sierra Leone.
# ==== Guinea (1 -> 1628) ====
# [0, 1628] (0, 1628)
# Projection: +proj=aeqd +R=6371000 +lat_0=9.63 +lon_0=-13.62 +no_defs
# Analyzing best overall circle...  Iterations: [7, 15]
# Fine-tuning the circle... Iterations: [7]
# Time to compute roundness: 8.210s.
# Result info: 0.702605 (302686.5416, 90068.4440) 279683.6741
# Finished plotting Guinea.
# ==== Liberia (1 -> 698) ====
# [0, 698] (0, 698)
# Projection: +proj=aeqd +R=6371000 +lat_0=7.56 +lon_0=-8.90 +no_defs
# Analyzing best overall circle...  Iterations: [11, 14]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 4.126s.
# Result info: 0.723695 (-82719.4061, -90006.1877) 174609.9278
# Finished plotting Liberia.
# ==== Central African Republic (1 -> 1792) ====
# [0, 1792] (0, 1792)
# Projection: +proj=aeqd +R=6371000 +lat_0=4.87 +lon_0=25.02 +no_defs
# Analyzing best overall circle...  Iterations: [14, 11]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 7.656s.
# Result info: 0.699882 (-459727.8241, 219722.3459) 444879.7981
# Finished plotting Central African Republic.
# ==== Sudan (2 -> 1174) ====
# [0, 1163, 1174] (0, 1163)
# Projection: +proj=aeqd +R=6371000 +lat_0=13.55 +lon_0=36.05 +no_defs
# Analyzing best overall circle...  Iterations: [10, 12]
# Analyzing best part circle... (1 out of 2) Iterations: [10, 12]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 9.319s.
# Result info: 0.890896 (-669131.4025, 278460.6327) 771335.1113
# Finished plotting Sudan.
# ==== Djibouti (1 -> 209) ====
# [0, 209] (0, 209)
# Projection: +proj=aeqd +R=6371000 +lat_0=11.76 +lon_0=43.26 +no_defs
# Analyzing best overall circle...  Iterations: [13, 17]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 2.897s.
# Result info: 0.799050 (-81943.2889, -7093.3636) 83574.0153
# Finished plotting Djibouti.
# ==== Eritrea (3 -> 1010) ====
# [0, 842, 980, 1010] (0, 842)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.38 +lon_0=39.79 +no_defs
# Analyzing best overall circle...  Iterations: [11, 20]
# Analyzing best part circle... (1 out of 3) Iterations: [11, 20]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 14.003s.
# Result info: 0.727657 (-160448.9651, 41013.9690) 197805.0843
# Finished plotting Eritrea.
# ==== Austria (1 -> 1094) ====
# [0, 1094] (0, 1094)
# Projection: +proj=aeqd +R=6371000 +lat_0=47.12 +lon_0=13.21 +no_defs
# Analyzing best overall circle...  Iterations: [11, 9]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 4.729s.
# Result info: 0.768822 (98372.9412, 63737.1493) 163306.8940
# Finished plotting Austria.
# ==== Iraq (1 -> 841) ====
# [0, 841] (0, 841)
# Projection: +proj=aeqd +R=6371000 +lat_0=35.87 +lon_0=43.08 +no_defs
# Analyzing best overall circle...  Iterations: [6, 11]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 3.066s.
# Result info: 0.791870 (68251.2962, -304807.5705) 373480.7818
# Finished plotting Iraq.
# ==== Italy (31 -> 3361) ====
# [0, 1951, 1970, 1977, 1999, 2016, 2373, 2386, 2407, 2418, 2449, 2464, 2485, 2515, 3096, 3109, 3176, 3188, 3200, 3211, 3216, 3227, 3237, 3254, 3260, 3278, 3289, 3309, 3330, 3336, 3352, 3361] (0, 1951)
# Projection: +proj=aeqd +R=6371000 +lat_0=42.17 +lon_0=15.25 +no_defs
# Analyzing best overall circle...  Iterations: [8, 12]
# Analyzing best part circle... (1 out of 31) Iterations: [15, 16]
# Fine-tuning the circle... Iterations: [11]
# Time to compute roundness: 38.229s.
# Result info: 0.560118 (-354323.8884, 243855.3167) 309683.3509
# Finished plotting Italy.
# ==== Switzerland (1 -> 749) ====
# [0, 749] (0, 749)
# Projection: +proj=aeqd +R=6371000 +lat_0=46.98 +lon_0=9.06 +no_defs
# Analyzing best overall circle...  Iterations: [9, 13]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 4.589s.
# Result info: 0.817462 (-69801.1996, -20733.5155) 114688.5769
# Finished plotting Switzerland.
# ==== Iran (12 -> 2728) ====
# [0, 2489, 2507, 2534, 2555, 2564, 2657, 2672, 2685, 2694, 2704, 2714, 2728] (0, 2489)
# Projection: +proj=aeqd +R=6371000 +lat_0=31.21 +lon_0=61.50 +no_defs
# Analyzing best overall circle...  Iterations: [13, 10]
# Analyzing best part circle... (1 out of 12) Iterations: [13, 10]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 24.403s.
# Result info: 0.803696 (-664678.0355, 160336.3323) 719942.4665
# Finished plotting Iran.
# ==== Liechtenstein (1 -> 29) ====
# [0, 29] (0, 29)
# Projection: +proj=aeqd +R=6371000 +lat_0=47.15 +lon_0=9.50 +no_defs
# Analyzing best overall circle...  Iterations: [21, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 2.301s.
# Result info: 0.686977 (2698.6796, -4201.3036) 6601.9669
# Finished plotting Liechtenstein.
# ==== Ivory Coast (2 -> 1599) ====
# [0, 1577, 1599] (0, 1577)
# Projection: +proj=aeqd +R=6371000 +lat_0=7.35 +lon_0=-3.58 +no_defs
# Analyzing best overall circle...  Iterations: [11, 13]
# Analyzing best part circle... (1 out of 2) Iterations: [11, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 19.066s.
# Result info: 0.899055 (-211469.7873, 42475.8699) 320240.1307
# Finished plotting Ivory Coast.
# ==== Republic of Serbia (1 -> 935) ====
# [0, 935] (0, 935)
# Projection: +proj=aeqd +R=6371000 +lat_0=43.22 +lon_0=20.96 +no_defs
# Analyzing best overall circle...  Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 4.973s.
# Result info: 0.766242 (-13213.7159, 119520.5759) 156985.7299
# Finished plotting Republic of Serbia.
# ==== Mali (1 -> 1747) ====
# [0, 1747] (0, 1747)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.95 +lon_0=-5.60 +no_defs
# Analyzing best overall circle...  Iterations: [20, 11]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 9.018s.
# Result info: 0.695675 (318021.1167, 201175.0659) 633297.3823
# Finished plotting Mali.
# ==== Senegal (1 -> 1378) ====
# [0, 1378] (0, 1378)
# Projection: +proj=aeqd +R=6371000 +lat_0=13.99 +lon_0=-16.60 +no_defs
# ...
# WARNING: circle.bounds == (). center = (191398.57183140298, 127739.99254558946), radius = 0.000
# WARNING: circle.bounds == (). center = (191398.57183140298, 125891.04287544699), radius = 0.000
# WARNING: circle.bounds == (). center = (191398.57183140298, 124042.09320530453), radius = 0.000
# WARNING: circle.bounds == (). center = (191398.57183140298, 88912.04947259772), radius = 0.000
# WARNING: circle.bounds == (). center = (156268.52809869617, 162870.03627829626), radius = 0.000
# WARNING: circle.bounds == (). center = (156268.52809869617, 127739.99254558946), radius = 0.000
# WARNING: circle.bounds == (). center = (156268.52809869617, 125891.04287544699), radius = 0.000
# WARNING: circle.bounds == (). center = (156268.52809869617, 124042.09320530453), radius = 0.000
# WARNING: circle.bounds == (). center = (156268.52809869617, 88912.04947259772), radius = 0.000
# [28, 29]
# Analyzing best part circle... (1 out of 22) Iterations: [14, 16]
# Analyzing best part circle... (2 out of 22) Iterations: [8, 14]
# Analyzing best part circle... (3 out of 22) Iterations: [22, 9]
# Analyzing best part circle... (4 out of 22) Iterations: [35, 10]
# Analyzing best part circle... (5 out of 22) Iterations: [16, 2]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 16.003s.
# Result info: 0.115559 (5805.3581, 9386.3725) 7256.5296
# Finished plotting Marshall Islands.
# ==== Trinidad and Tobago (2 -> 196) ====
# [0, 150, 196] (0, 150)
# Projection: +proj=aeqd +R=6371000 +lat_0=10.59 +lon_0=-61.48 +no_defs
# Analyzing best overall circle...  Iterations: [14, 12]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 14]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 5.555s.
# Result info: 0.758166 (18716.3087, -17717.7394) 40467.7644
# Finished plotting Trinidad and Tobago.
# ==== Grenada (2 -> 64) ====
# [0, 44, 64] (0, 44)
# Projection: +proj=aeqd +R=6371000 +lat_0=12.05 +lon_0=-61.73 +no_defs
# Analyzing best overall circle...  Iterations: [12, 15]
# Analyzing best part circle... (1 out of 2) Iterations: [8, 12]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 3.738s.
# Result info: 0.744056 (5925.7002, 8088.1531) 10536.2486
# Finished plotting Grenada.
# ==== Saint Vincent and the Grenadines (5 -> 83) ====
# [0, 23, 47, 60, 76, 83] (23, 47)
# Projection: +proj=aeqd +R=6371000 +lat_0=13.34 +lon_0=-61.22 +no_defs
# Analyzing best overall circle...  Iterations: [28, 14]
# Analyzing best part circle... (1 out of 5) Iterations: [10, 14]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 5.157s.
# Result info: 0.777442 (2870.3052, -9861.8355) 10835.6980
# Finished plotting Saint Vincent and the Grenadines.
# ==== Barbados (1 -> 35) ====
# [0, 35] (0, 35)
# Projection: +proj=aeqd +R=6371000 +lat_0=13.22 +lon_0=-59.63 +no_defs
# Analyzing best overall circle...  Iterations: [14, 15]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 2.082s.
# Result info: 0.794278 (9512.4499, -5646.0124) 11911.4037
# Finished plotting Barbados.
# ==== Saint Lucia (1 -> 50) ====
# [0, 50] (0, 50)
# Projection: +proj=aeqd +R=6371000 +lat_0=13.89 +lon_0=-60.96 +no_defs
# Analyzing best overall circle...  Iterations: [13, 16]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 2.235s.
# Result info: 0.775114 (-1699.4417, -1208.2044) 13905.1827
# Finished plotting Saint Lucia.
# ==== Dominica (1 -> 75) ====
# [0, 75] (0, 75)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.27 +lon_0=-61.27 +no_defs
# Analyzing best overall circle...  Iterations: [10, 16]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 2.186s.
# Result info: 0.728031 (-10581.3434, 20680.9869) 15278.0255
# Finished plotting Dominica.
# ==== Antigua and Barbuda (2 -> 108) ====
# [0, 63, 108] (0, 63)
# Projection: +proj=aeqd +R=6371000 +lat_0=17.07 +lon_0=-61.78 +no_defs
# Analyzing best overall circle...  Iterations: [1, 17]
# Analyzing best part circle... (1 out of 2) Iterations: [8, 17]
# Fine-tuning the circle... Iterations: [7]
# Time to compute roundness: 3.661s.
# Result info: 0.623951 (-318.0277, 273.8073) 12003.7213
# Finished plotting Antigua and Barbuda.
# ==== Saint Kitts and Nevis (2 -> 43) ====
# [0, 15, 43] (15, 43)
# Projection: +proj=aeqd +R=6371000 +lat_0=17.33 +lon_0=-62.73 +no_defs
# Analyzing best overall circle...  Iterations: [13, 17]
# Analyzing best part circle... (1 out of 2) Iterations: [9, 16]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 3.975s.
# Result info: 0.539953 (-4890.9710, 1880.4989) 9185.3067
# Finished plotting Saint Kitts and Nevis.
# ==== Jamaica (1 -> 254) ====
# [0, 254] (0, 254)
# Projection: +proj=aeqd +R=6371000 +lat_0=18.43 +lon_0=-78.00 +no_defs
# Analyzing best overall circle...  Iterations: [12, 15]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 3.027s.
# Result info: 0.681505 (64728.9778, -26978.1694) 59334.1298
# Finished plotting Jamaica.
# ==== Mauritius (3 -> 113) ====
# [0, 83, 95, 113] (0, 83)
# Projection: +proj=aeqd +R=6371000 +lat_0=-20.38 +lon_0=57.37 +no_defs
# Analyzing best overall circle...  Iterations: [1, 23]
# Analyzing best part circle... (1 out of 3) Iterations: [14, 20]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 3.987s.
# Result info: 0.830345 (19721.9448, 11360.9236) 25367.8230
# Finished plotting Mauritius.
# ==== Comoros (3 -> 127) ====
# [0, 25, 69, 127] (69, 127)
# Projection: +proj=aeqd +R=6371000 +lat_0=-11.42 +lon_0=43.26 +no_defs
# Analyzing best overall circle...  Iterations: [17, 17]
# Analyzing best part circle... (1 out of 3) Iterations: [8, 23]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 4.625s.
# Result info: 0.484467 (10655.8950, -25299.3989) 23105.9214
# Finished plotting Comoros.
# ==== São Tomé and Principe (2 -> 96) ====
# [0, 54, 96] (0, 54)
# Projection: +proj=aeqd +R=6371000 +lat_0=0.24 +lon_0=6.61 +no_defs
# Analyzing best overall circle...  Iterations: [22, 19]
# Analyzing best part circle... (1 out of 2) Iterations: [12, 10]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 3.872s.
# Result info: 0.787632 (633.3301, 93.7104) 18213.0601
# Finished plotting São Tomé and Principe.
# ==== Cabo Verde (9 -> 409) ====
# [0, 23, 49, 144, 190, 235, 275, 318, 357, 409] (49, 144)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.19 +lon_0=-23.65 +no_defs
# Analyzing best overall circle...  Iterations: [18, 6]
# Analyzing best part circle... (1 out of 9) Iterations: [6, 18]
# Analyzing best part circle... (2 out of 9) Iterations: [11, 4]
# Analyzing best part circle... (3 out of 9) Iterations: [3, 2]
# Analyzing best part circle... (4 out of 9) Iterations: [3, 2]
# Analyzing best part circle... (5 out of 9) Iterations: [11, 2]
# Fine-tuning the circle... Iterations: [12]
# Time to compute roundness: 9.666s.
# Result info: 0.298993 (20685.6543, -2318.6143) 35215.7767
# Finished plotting Cabo Verde.
# ==== Malta (2 -> 55) ====
# [0, 38, 55] (0, 38)
# Projection: +proj=aeqd +R=6371000 +lat_0=35.91 +lon_0=14.36 +no_defs
# Analyzing best overall circle...  Iterations: [16, 15]
# Analyzing best part circle... (1 out of 2) Iterations: [15, 15]
# Fine-tuning the circle... Iterations: [4]
# Time to compute roundness: 4.189s.
# Result info: 0.716289 (8375.7095, -2384.2904) 10177.5783
# Finished plotting Malta.
# ==== Singapore (1 -> 40) ====
# [0, 40] (0, 40)
# Projection: +proj=aeqd +R=6371000 +lat_0=1.45 +lon_0=103.80 +no_defs
# Analyzing best overall circle...  Iterations: [12, 12]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 1.650s.
# Result info: 0.776195 (-607.0854, -9708.0889) 12774.0511
# Finished plotting Singapore.
# ==== Tonga (10 -> 212) ====
# [0, 42, 65, 124, 140, 159, 172, 184, 193, 203, 212] (65, 124)
# Projection: +proj=aeqd +R=6371000 +lat_0=-21.18 +lon_0=-175.28 +no_defs
# Analyzing best overall circle...  Iterations: [22, 30]
# Analyzing best part circle... (1 out of 10) Iterations: [6, 14]
# Analyzing best part circle... (2 out of 10) Iterations: [3, 2]
# Analyzing best part circle... (3 out of 10) Iterations: [16, 2]
# Analyzing best part circle... (4 out of 10) Iterations: [10, 2]
# Analyzing best part circle... (5 out of 10) Iterations: [3, 2]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 8.678s.
# Result info: 0.378203 (8552.8529, 2646.1163) 13878.4965
# Finished plotting Tonga.
# ==== Samoa (2 -> 132) ====
# [0, 77, 132] (0, 77)
# Projection: +proj=aeqd +R=6371000 +lat_0=-13.54 +lon_0=-172.58 +no_defs
# Analyzing best overall circle...  Iterations: [20, 17]
# Analyzing best part circle... (1 out of 2) Iterations: [19, 14]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 4.972s.
# Result info: 0.572648 (13617.5086, -11953.9409) 29807.2863
# Finished plotting Samoa.
# ==== Solomon Islands (48 -> 2177) ====
# [0, 84, 97, 113, 305, 314, 319, 339, 391, 548, 561, 594, 615, 667, 702, 716, 742, 767, 842, 899, 927, 936, 1115, 1137, 1162, 1170, 1322, 1346, 1373, 1440, 1454, 1486, 1535, 1560, 1583, 1630, 1672, 1879, 1907, 1933, 1955, 1973, 2111, 2119, 2130, 2140, 2150, 2167, 2177] (1672, 1879)
# Projection: +proj=aeqd +R=6371000 +lat_0=-8.11 +lon_0=159.31 +no_defs
# Analyzing best overall circle...  Iterations: [13, 19]
# Analyzing best part circle... (1 out of 48) Iterations: [33, 15]
# Analyzing best part circle... (2 out of 48) Iterations: [29, 22]
# Analyzing best part circle... (3 out of 48) Iterations: [20, 27]
# Analyzing best part circle... (4 out of 48) Iterations: [31, 13]
# Analyzing best part circle... (5 out of 48) Iterations: [27, 22]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 63.819s.
# Result info: 0.333211 (119508.5606, -115191.5762) 93229.5408
# Finished plotting Solomon Islands.
# ==== Tuvalu (9 -> 69) ====
# [0, 13, 19, 27, 32, 40, 46, 53, 60, 69] (0, 13)
# Projection: +proj=aeqd +R=6371000 +lat_0=-8.52 +lon_0=179.21 +no_defs
# Analyzing best overall circle...  Iterations: [27, 29]
# Analyzing best part circle... (1 out of 9) Iterations: [21, 12]
# Analyzing best part circle... (2 out of 9) Iterations: [17, 7]
# Analyzing best part circle... (3 out of 9) Iterations: [19, 2]
# Analyzing best part circle... (4 out of 9) Iterations: [7, 2]
# Analyzing best part circle... (5 out of 9) Iterations: [9, 2]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 9.105s.
# Result info: 0.278355 (-799.4543, 1408.1984) 2712.5274
# Finished plotting Tuvalu.
# ==== Maldives (176 -> 1453) ====
# [0, 5, 13, 19, 25, 35, 43, 55, 62, 73, 80, 90, 99, 107, 112, 119, 129, 141, 155, 167, 179, 186, 196, 208, 215, 229, 237, 247, 252, 257, 264, 274, 284, 292, 298, 304, 309, 317, 322, 332, 337, 344, 350, 354, 360, 369, 374, 382, 387, 393, 397, 407, 421, 426, 430, 436, 446, 457, 462, 473, 485, 497, 512, 520, 533, 539, 552, 561, 568, 575, 581, 590, 596, 600, 607, 617, 623, 633, 640, 645, 651, 657, 666, 675, 680, 689, 696, 703, 713, 719, 726, 736, 744, 750, 757, 763, 773, 777, 787, 797, 808, 819, 827, 835, 841, 850, 861, 871, 880, 886, 891, 897, 913, 920, 926, 936, 949, 958, 964, 975, 983, 993, 1002, 1013, 1022, 1031, 1036, 1047, 1056, 1064, 1070, 1081, 1086, 1091, 1102, 1107, 1113, 1118, 1129, 1134, 1141, 1147, 1156, 1161, 1168, 1174, 1186, 1192, 1201, 1210, 1220, 1232, 1237, 1247, 1256, 1268, 1278, 1284, 1293, 1305, 1315, 1328, 1334, 1345, 1354, 1365, 1377, 1388, 1398, 1408, 1413, 1425, 1430, 1436, 1441, 1448, 1453] (897, 913)
# Projection: +proj=aeqd +R=6371000 +lat_0=4.18 +lon_0=73.51 +no_defs
# Analyzing best overall circle...  Iterations: [11, 27]
# Analyzing best part circle... (1 out of 176) Iterations: [11, 9]
# Analyzing best part circle... (2 out of 176) Iterations: [12, 2]
# Analyzing best part circle... (3 out of 176) Iterations: [15, 2]
# Analyzing best part circle... (4 out of 176) Iterations: [32, 2]
# Analyzing best part circle... (5 out of 176) Iterations: [19, 2]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 26.578s.
# Result info: 0.289337 (-917.3876, 3049.0473) 5895.9718
# Finished plotting Maldives.
# ==== Nauru (1 -> 9) ====
# [0, 9] (0, 9)
# Projection: +proj=aeqd +R=6371000 +lat_0=-0.49 +lon_0=166.95 +no_defs
# Analyzing best overall circle...  Iterations: [9, 8]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 1.188s.
# Result info: 0.923060 (-1825.7860, -3430.1930) 3032.5733
# Finished plotting Nauru.
# ==== Federated States of Micronesia (20 -> 254) ====
# [0, 24, 74, 96, 111, 144, 152, 158, 166, 171, 176, 185, 194, 203, 210, 218, 224, 230, 239, 247, 254] (24, 74)
# Projection: +proj=aeqd +R=6371000 +lat_0=6.87 +lon_0=158.32 +no_defs
# Analyzing best overall circle...  Iterations: [23, 28]
# Analyzing best part circle... (1 out of 20) Iterations: [3, 2]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 5.200s.
# Result info: 0.535491 (-7821.6678, 3382.1716) 14254.8136
# Finished plotting Federated States of Micronesia.
# ==== Vanuatu (27 -> 1015) ====
# [0, 23, 70, 127, 220, 231, 240, 255, 266, 333, 344, 355, 399, 559, 577, 598, 632, 654, 664, 704, 861, 893, 936, 951, 968, 981, 1010, 1015] (399, 559)
# Projection: +proj=aeqd +R=6371000 +lat_0=-16.35 +lon_0=167.55 +no_defs
# Analyzing best overall circle...  Iterations: [24, 21]
# Analyzing best part circle... (1 out of 27) Iterations: [10, 3]
# Analyzing best part circle... (2 out of 27) Iterations: [19, 13]
# Analyzing best part circle... (3 out of 27) Iterations: [5, 2]
# Analyzing best part circle... (4 out of 27) Iterations: [7, 2]
# Analyzing best part circle... (5 out of 27) Iterations: [41, 34]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 31.120s.
# Result info: 0.340252 (-71442.9937, 127009.9935) 62659.1126
# Finished plotting Vanuatu.
# ==== Palau (9 -> 165) ====
# [0, 16, 46, 62, 126, 135, 140, 149, 157, 165] (62, 126)
# Projection: +proj=aeqd +R=6371000 +lat_0=7.59 +lon_0=134.55 +no_defs
# Analyzing best overall circle...  Iterations: [21, 23]
# Analyzing best part circle... (1 out of 9) Iterations: [13, 18]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 6.849s.
# Result info: 0.554287 (3541.8991, -10360.7459) 12541.3770
# Finished plotting Palau.
# ==== Bahrain (1 -> 50) ====
# [0, 50] (0, 50)
# Projection: +proj=aeqd +R=6371000 +lat_0=26.09 +lon_0=50.54 +no_defs
# Analyzing best overall circle...  Iterations: [9, 9]
# Fine-tuning the circle... Iterations: [6]
# Time to compute roundness: 2.032s.
# Result info: 0.649275 (-42.6197, -3152.7662) 13652.5928
# Finished plotting Bahrain.
# ==== Spratly Islands (12 -> 102) ====
# [0, 4, 16, 23, 32, 40, 48, 56, 69, 81, 89, 98, 102] (56, 69)
# Projection: +proj=aeqd +R=6371000 +lat_0=10.73 +lon_0=115.82 +no_defs
# Analyzing best overall circle...  Iterations: [8, 7]
# Analyzing best part circle... (1 out of 12) Iterations: [5, 2]
# Analyzing best part circle... (2 out of 12) Iterations: [9, 2]
# Analyzing best part circle... (3 out of 12) Iterations: [3, 2]
# Analyzing best part circle... (4 out of 12) Iterations: [6, 2]
# Analyzing best part circle... (5 out of 12) Iterations: [4, 2]
# Fine-tuning the circle... Iterations: [2]
# Time to compute roundness: 4.578s.
# Result info: 0.198786 (547.5788, -1.2191) 1604.1639
# Finished plotting Spratly Islands.
# ==== Bajo Nuevo Bank (Petrel Is.) (1 -> 5) ====
# [0, 5] (0, 5)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.80 +lon_0=-79.99 +no_defs
# Analyzing best overall circle...  Iterations: [14, 13]
# Fine-tuning the circle... Iterations: [3]
# Time to compute roundness: 2.042s.
# Result info: 0.859750 (226.4392, -550.7256) 106.9991
# Finished plotting Bajo Nuevo Bank (Petrel Is.).
# ==== Serranilla Bank (1 -> 4) ====
# [0, 4] (0, 4)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.86 +lon_0=-78.64 +no_defs
# Analyzing best overall circle...  Iterations: [11, 16]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 2.309s.
# Result info: 0.797722 (195.7130, 484.6105) 183.3619
# Finished plotting Serranilla Bank.
# ==== Scarborough Reef (1 -> 5) ====
# [0, 5] (0, 5)
# Projection: +proj=aeqd +R=6371000 +lat_0=15.15 +lon_0=117.75 +no_defs
# Analyzing best overall circle...  Iterations: [10, 13]
# Fine-tuning the circle... Iterations: [5]
# Time to compute roundness: 1.944s.
# Result info: 0.900772 (408.9542, 232.0894) 176.7230
# Finished plotting Scarborough Reef.
